# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('dati_fin.csv', sep=';')
del_col = ['Darījuma datums']
data = data.drop(columns=del_col)

# %%
# rindu un kolonu skaits
data.shape
# Out:
# (4518, 17)

# %%
# Datu tipi
data.dtypes
# Out:
# Darījuma summa, EUR                     float64
# Pārdotā zemes kopplatība, m2            float64
# Būvju skaits                              int64
# Būves virszemes stāvu skaits              int64
# Būves apbūves laukums, m2               float64
# Būves kopplatība, m2                    float64
# Būves būvtilpums, m3                    float64
# Būves ekspluatācijas uzsākšanas gads      int64
# Būves fiziskais nolietojums, %            int64
# Telpu grupas zemākais stāvs               int64
# Telpu grupas augstākais stāvs             int64
# Telpu grupas platība, m2                float64
# Dzīvokļa kopplatība, m2                 float64
# Telpu skaits telpu grupā                  int64
# Istabu skaits dzīvoklī                    int64
# Garums                                  float64
# Platums                                 float64
# dtype: object

# %%
# Vai ir kādas tukšas vērtības
data.isnull().sum()
# Out:
# Darījuma summa, EUR                     0
# Pārdotā zemes kopplatība, m2            0
# Būvju skaits                            0
# Būves virszemes stāvu skaits            0
# Būves apbūves laukums, m2               0
# Būves kopplatība, m2                    0
# Būves būvtilpums, m3                    0
# Būves ekspluatācijas uzsākšanas gads    0
# Būves fiziskais nolietojums, %          0
# Telpu grupas zemākais stāvs             0
# Telpu grupas augstākais stāvs           0
# Telpu grupas platība, m2                0
# Dzīvokļa kopplatība, m2                 0
# Telpu skaits telpu grupā                0
# Istabu skaits dzīvoklī                  0
# Garums                                  0
# Platums                                 0
# dtype: int64

# %%
data.describe()
# Out:
#        Darījuma summa, EUR  Pārdotā zemes kopplatība, m2  Būvju skaits  \
# count          4518.000000                   4518.000000   4518.000000
# mean          16172.085952                    110.447822      1.341965
# std           15812.047871                    128.102990      0.830920
# min            1000.000000                      3.010000      1.000000
# 25%            5000.000000                     42.352500      1.000000
# 50%           10000.000000                     72.465000      1.000000
# 75%           23000.000000                    127.040000      1.000000
# max          120000.000000                   1845.900000      9.000000
#
#        Būves virszemes stāvu skaits  Būves apbūves laukums, m2  \
# count                   4518.000000                4518.000000
# mean                       3.918105                 598.991558
# std                        1.462217                 301.686113
# min                        1.000000                  82.000000
# 25%                        3.000000                 364.300000
# 50%                        4.000000                 592.850000
# 75%                        5.000000                 824.700000
# max                       10.000000                1789.800000
#
#        Būves kopplatība, m2  Būves būvtilpums, m3  \
# count           4518.000000           4518.000000
# mean            2410.202036           8368.986941
# std             1633.497569           5639.246244
# min               85.300000            284.000000
# 25%              828.350000           3066.000000
# 50%             2403.500000           8278.000000
# 75%             3571.625000          11752.000000
# max             7628.000000          25254.000000
#
#        Būves ekspluatācijas uzsākšanas gads  Būves fiziskais nolietojums, %  \
# count                           4518.000000                     4518.000000
# mean                            1966.282426                       28.638336
# std                               30.253616                       15.799966
# min                             1630.000000                        0.000000
# 25%                             1963.000000                       15.000000
# 50%                             1974.000000                       28.000000
# 75%                             1983.000000                       36.000000
# max                             2022.000000                       90.000000
#
#        Telpu grupas zemākais stāvs  Telpu grupas augstākais stāvs  \
# count                  4518.000000                    4518.000000
# mean                      2.502213                       2.516600
# std                       1.396212                       1.389439
# min                      -1.000000                      -1.000000
# 25%                       1.000000                       1.000000
# 50%                       2.000000                       2.000000
# 75%                       3.000000                       3.000000
# max                       9.000000                       9.000000
#
#        Telpu grupas platība, m2  Dzīvokļa kopplatība, m2  \
# count               4518.000000              4518.000000
# mean                  47.599402                45.728132
# std                   16.356162                14.929352
# min                    9.400000                 9.400000
# 25%                   35.800000                35.000000
# 50%                   46.300000                45.500000
# 75%                   56.300000                53.700000
# max                  208.300000               200.900000
#
#        Telpu skaits telpu grupā  Istabu skaits dzīvoklī       Garums  \
# count               4518.000000             4518.000000  4518.000000
# mean                   5.952191                1.970120    56.871865
# std                    2.088144                0.793343     0.350109
# min                    1.000000                1.000000    56.300000
# 25%                    5.000000                1.000000    56.597500
# 50%                    6.000000                2.000000    56.966667
# 75%                    7.000000                2.000000    57.172500
# max                   22.000000                5.000000    57.863889
#
#            Platums
# count  4518.000000
# mean     24.598837
# std       1.912286
# min      21.166111
# 25%      22.775000
# 50%      24.357222
# 75%      26.219444
# max      27.726944

# %%
corr = data.corr()
corr.shape
# Out:
# (17, 17)

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(corr, annot=True, fmt='.2f', annot_kws={'size':16}, cmap='coolwarm')
# Out:
# <Axes: >
