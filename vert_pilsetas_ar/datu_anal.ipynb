# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('dati_gg.csv', sep=';')

# %%
# rindu un kolonu skaits
data.shape
# Out:
# (4518, 18)

# %%
# Datu tipi
data.dtypes
# Out:
# Darījuma summa, EUR                     float64
# Pārdotā zemes kopplatība, m2            float64
# Būvju skaits                              int64
# Būves virszemes stāvu skaits              int64
# Būves kopplatība, m2                    float64
# Būves ekspluatācijas uzsākšanas gads      int64
# Būves fiziskais nolietojums, %            int64
# Telpu grupas platība, m2                float64
# Telpu skaits telpu grupā                  int64
# Istabu skaits dzīvoklī                    int64
# Garums                                  float64
# Platums                                 float64
# Telpu grupas vidējais stāvs             float64
# Gads                                      int64
# sezona_Pavasaris                          int64
# sezona_Rudens                             int64
# sezona_Vasara                             int64
# sezona_Ziema                              int64
# dtype: object

# %%
# Vai ir kādas tukšas vērtības
data.isnull().sum()
# Out:
# Darījuma summa, EUR                     0
# Pārdotā zemes kopplatība, m2            0
# Būvju skaits                            0
# Būves virszemes stāvu skaits            0
# Būves kopplatība, m2                    0
# Būves ekspluatācijas uzsākšanas gads    0
# Būves fiziskais nolietojums, %          0
# Telpu grupas platība, m2                0
# Telpu skaits telpu grupā                0
# Istabu skaits dzīvoklī                  0
# Garums                                  0
# Platums                                 0
# Telpu grupas vidējais stāvs             0
# Gads                                    0
# sezona_Pavasaris                        0
# sezona_Rudens                           0
# sezona_Vasara                           0
# sezona_Ziema                            0
# dtype: int64

# %%
data.describe()
# Out:
#        Darījuma summa, EUR  Pārdotā zemes kopplatība, m2  Būvju skaits  \
# count          4518.000000                   4518.000000   4518.000000
# mean          16172.085952                    110.447822      1.341965
# std           15812.047871                    128.102990      0.830920
# min            1000.000000                      3.010000      1.000000
# 25%            5000.000000                     42.352500      1.000000
# 50%           10000.000000                     72.465000      1.000000
# 75%           23000.000000                    127.040000      1.000000
# max          120000.000000                   1845.900000      9.000000
#
#        Būves virszemes stāvu skaits  Būves kopplatība, m2  \
# count                   4518.000000           4518.000000
# mean                       3.918105           2410.202036
# std                        1.462217           1633.497569
# min                        1.000000             85.300000
# 25%                        3.000000            828.350000
# 50%                        4.000000           2403.500000
# 75%                        5.000000           3571.625000
# max                       10.000000           7628.000000
#
#        Būves ekspluatācijas uzsākšanas gads  Būves fiziskais nolietojums, %  \
# count                           4518.000000                     4518.000000
# mean                            1966.282426                       28.638336
# std                               30.253616                       15.799966
# min                             1630.000000                        0.000000
# 25%                             1963.000000                       15.000000
# 50%                             1974.000000                       28.000000
# 75%                             1983.000000                       36.000000
# max                             2022.000000                       90.000000
#
#        Telpu grupas platība, m2  Telpu skaits telpu grupā  \
# count               4518.000000               4518.000000
# mean                  47.599402                  5.952191
# std                   16.356162                  2.088144
# min                    9.400000                  1.000000
# 25%                   35.800000                  5.000000
# 50%                   46.300000                  6.000000
# 75%                   56.300000                  7.000000
# max                  208.300000                 22.000000
#
#        Istabu skaits dzīvoklī       Garums      Platums  \
# count             4518.000000  4518.000000  4518.000000
# mean                 1.970120    56.871865    24.598837
# std                  0.793343     0.350109     1.912286
# min                  1.000000    56.300000    21.166111
# 25%                  1.000000    56.597500    22.775000
# 50%                  2.000000    56.966667    24.357222
# 75%                  2.000000    57.172500    26.219444
# max                  5.000000    57.863889    27.726944
#
#        Telpu grupas vidējais stāvs         Gads  sezona_Pavasaris  \
# count                  4518.000000  4518.000000       4518.000000
# mean                      2.509407  2021.227313          0.241700
# std                       1.390800     1.773639          0.428161
# min                      -1.000000  2000.000000          0.000000
# 25%                       1.000000  2020.000000          0.000000
# 50%                       2.000000  2021.000000          0.000000
# 75%                       3.000000  2022.000000          0.000000
# max                       9.000000  2023.000000          1.000000
#
#        sezona_Rudens  sezona_Vasara  sezona_Ziema
# count    4518.000000    4518.000000   4518.000000
# mean        0.254537       0.267375      0.236388
# std         0.435649       0.442639      0.424910
# min         0.000000       0.000000      0.000000
# 25%         0.000000       0.000000      0.000000
# 50%         0.000000       0.000000      0.000000
# 75%         1.000000       1.000000      0.000000
# max         1.000000       1.000000      1.000000

# %%
corr = data.corr()
corr.shape
# Out:
# (18, 18)

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(corr, annot=True, fmt='.2f', annot_kws={'size':16}, cmap='coolwarm')
# Out:
# <Axes: >
