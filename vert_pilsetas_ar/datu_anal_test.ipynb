# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('2024_gg.csv', sep=';')

# %%
# rindu un kolonu skaits
data.shape
# Out:
# (1103, 18)

# %%
# Datu tipi
data.dtypes
# Out:
# Darījuma summa, EUR                     float64
# Pārdotā zemes kopplatība, m2            float64
# Būvju skaits                              int64
# Būves virszemes stāvu skaits              int64
# Būves kopplatība, m2                    float64
# Būves ekspluatācijas uzsākšanas gads      int64
# Būves fiziskais nolietojums, %          float64
# Telpu grupas platība, m2                float64
# Telpu skaits telpu grupā                  int64
# Istabu skaits dzīvoklī                    int64
# Garums                                  float64
# Platums                                 float64
# Telpu grupas vidējais stāvs             float64
# Gads                                      int64
# sezona_Pavasaris                          int64
# sezona_Rudens                             int64
# sezona_Vasara                             int64
# sezona_Ziema                              int64
# dtype: object

# %%
# Vai ir kādas tukšas vērtības
data.isnull().sum()
# Out:
# Darījuma summa, EUR                     0
# Pārdotā zemes kopplatība, m2            0
# Būvju skaits                            0
# Būves virszemes stāvu skaits            0
# Būves kopplatība, m2                    0
# Būves ekspluatācijas uzsākšanas gads    0
# Būves fiziskais nolietojums, %          0
# Telpu grupas platība, m2                0
# Telpu skaits telpu grupā                0
# Istabu skaits dzīvoklī                  0
# Garums                                  0
# Platums                                 0
# Telpu grupas vidējais stāvs             0
# Gads                                    0
# sezona_Pavasaris                        0
# sezona_Rudens                           0
# sezona_Vasara                           0
# sezona_Ziema                            0
# dtype: int64

# %%
data.describe()
# Out:
#        Darījuma summa, EUR  Pārdotā zemes kopplatība, m2  Būvju skaits  \
# count          1103.000000                   1103.000000   1103.000000
# mean          19178.931877                    121.956183      1.404352
# std           17443.019670                    208.448532      0.902537
# min            1000.000000                      7.640000      1.000000
# 25%            6500.000000                     44.940000      1.000000
# 50%           14000.000000                     73.310000      1.000000
# 75%           26240.135000                    136.810000      1.000000
# max          122500.000000                   4313.150000      9.000000
#
#        Būves virszemes stāvu skaits  Būves kopplatība, m2  \
# count                   1103.000000           1103.000000
# mean                       3.769719           2277.671623
# std                        1.497581           1692.130449
# min                        1.000000             87.100000
# 25%                        2.000000            596.650000
# 50%                        4.000000           2217.600000
# 75%                        5.000000           3516.400000
# max                       10.000000           7190.100000
#
#        Būves ekspluatācijas uzsākšanas gads  Būves fiziskais nolietojums, %  \
# count                           1103.000000                     1103.000000
# mean                            1962.288305                       30.648232
# std                               33.274968                       15.623738
# min                             1750.000000                        0.000000
# 25%                             1960.000000                       20.000000
# 50%                             1973.000000                       30.000000
# 75%                             1982.000000                       40.000000
# max                             2008.000000                       75.000000
#
#        Telpu grupas platība, m2  Telpu skaits telpu grupā  \
# count               1103.000000               1103.000000
# mean                  46.768359                  5.869447
# std                   17.096562                  2.108491
# min                   10.600000                  1.000000
# 25%                   34.850000                  4.000000
# 50%                   45.500000                  6.000000
# 75%                   55.100000                  7.000000
# max                  191.700000                 14.000000
#
#        Istabu skaits dzīvoklī       Garums      Platums  \
# count             1103.000000  1103.000000  1103.000000
# mean                 1.930190    56.872709    24.424743
# std                  0.795646     0.347627     1.885181
# min                  1.000000    56.300000    21.166111
# 25%                  1.000000    56.597500    22.588611
# 50%                  2.000000    56.966667    24.196667
# 75%                  2.000000    57.172500    26.183333
# max                  7.000000    57.751667    27.726944
#
#        Telpu grupas vidējais stāvs         Gads  sezona_Pavasaris  \
# count                  1103.000000  1103.000000       1103.000000
# mean                      2.365367  2023.674524          0.222121
# std                       1.333213     1.578023          0.415861
# min                      -1.000000  2001.000000          0.000000
# 25%                       1.000000  2024.000000          0.000000
# 50%                       2.000000  2024.000000          0.000000
# 75%                       3.000000  2024.000000          0.000000
# max                       9.000000  2024.000000          1.000000
#
#        sezona_Rudens  sezona_Vasara  sezona_Ziema
# count    1103.000000    1103.000000   1103.000000
# mean        0.289211       0.292838      0.195830
# std         0.453602       0.455271      0.397018
# min         0.000000       0.000000      0.000000
# 25%         0.000000       0.000000      0.000000
# 50%         0.000000       0.000000      0.000000
# 75%         1.000000       1.000000      0.000000
# max         1.000000       1.000000      1.000000

# %%
corr = data.corr()
corr.shape
# Out:
# (18, 18)

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(corr, annot=True, fmt='.2f', annot_kws={'size':16}, cmap='coolwarm')
# Out:
# <Axes: >
