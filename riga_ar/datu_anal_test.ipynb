# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('2024_fin.csv', sep=';')

# %%
# rindu un kolonu skaits
data.shape
# Out:
# (5782, 18)

# %%
# Datu tipi
data.dtypes
# Out:
# Darījuma summa, EUR                     float64
# Pārdotā zemes kopplatība, m2            float64
# Būvju skaits                              int64
# Būves virszemes stāvu skaits              int64
# Būves kopplatība, m2                    float64
# Būves ekspluatācijas uzsākšanas gads      int64
# Būves fiziskais nolietojums, %          float64
# Telpu grupas platība, m2                float64
# Telpu skaits telpu grupā                  int64
# Istabu skaits dzīvoklī                    int64
# Telpu grupas vidējais stāvs             float64
# Gads                                      int64
# sezona_Pavasaris                          int64
# sezona_Rudens                             int64
# sezona_Vasara                             int64
# sezona_Ziema                              int64
# Platums                                 float64
# Garums                                  float64
# dtype: object

# %%
# Vai ir kādas tukšas vērtības
data.isnull().sum()
# Out:
# Darījuma summa, EUR                     0
# Pārdotā zemes kopplatība, m2            0
# Būvju skaits                            0
# Būves virszemes stāvu skaits            0
# Būves kopplatība, m2                    0
# Būves ekspluatācijas uzsākšanas gads    0
# Būves fiziskais nolietojums, %          0
# Telpu grupas platība, m2                0
# Telpu skaits telpu grupā                0
# Istabu skaits dzīvoklī                  0
# Telpu grupas vidējais stāvs             0
# Gads                                    0
# sezona_Pavasaris                        0
# sezona_Rudens                           0
# sezona_Vasara                           0
# sezona_Ziema                            0
# Platums                                 0
# Garums                                  0
# dtype: int64

# %%
data.describe()
# Out:
#        Darījuma summa, EUR  Pārdotā zemes kopplatība, m2  Būvju skaits  \
# count         5.782000e+03                   5782.000000   5782.000000
# mean          7.942028e+04                     59.779773      1.702006
# std           7.019177e+04                     55.768516      1.578788
# min           1.000000e+03                      0.630000      1.000000
# 25%           3.080575e+04                     32.382500      1.000000
# 50%           5.500000e+04                     48.680000      1.000000
# 75%           1.128750e+05                     69.677500      2.000000
# max           1.385000e+06                   1966.680000     18.000000
#
#        Būves virszemes stāvu skaits  Būves kopplatība, m2  \
# count                   5782.000000           5782.000000
# mean                       6.000519           4326.911726
# std                        3.324595           3682.951283
# min                        1.000000             80.400000
# 25%                        4.000000           1647.500000
# 50%                        5.000000           3643.250000
# 75%                        7.000000           5530.875000
# max                       31.000000          28589.000000
#
#        Būves ekspluatācijas uzsākšanas gads  Būves fiziskais nolietojums, %  \
# count                           5782.000000                     5782.000000
# mean                            1964.986856                       25.895884
# std                               43.643745                       19.098165
# min                             1760.000000                        0.000000
# 25%                             1920.000000                       10.000000
# 50%                             1970.000000                       29.000000
# 75%                             2006.000000                       35.000000
# max                             2024.000000                       80.000000
#
#        Telpu grupas platība, m2  Telpu skaits telpu grupā  \
# count               5782.000000               5782.000000
# mean                  55.136821                  5.777759
# std                   30.858839                  2.549541
# min                    7.100000                  1.000000
# 25%                   37.800000                  4.000000
# 50%                   49.000000                  5.000000
# 75%                   64.975000                  7.000000
# max                  546.700000                 27.000000
#
#        Istabu skaits dzīvoklī  Telpu grupas vidējais stāvs         Gads  \
# count             5782.000000                  5782.000000  5782.000000
# mean                 2.181771                     3.403061  2023.945694
# std                  0.999218                     2.422539     0.378214
# min                  1.000000                    -1.000000  2007.000000
# 25%                  1.000000                     2.000000  2024.000000
# 50%                  2.000000                     3.000000  2024.000000
# 75%                  3.000000                     4.500000  2024.000000
# max                 10.000000                    24.000000  2024.000000
#
#        sezona_Pavasaris  sezona_Rudens  sezona_Vasara  sezona_Ziema  \
# count       5782.000000    5782.000000    5782.000000   5782.000000
# mean           0.235213       0.288654       0.255794      0.220339
# std            0.424168       0.453176       0.436344      0.414511
# min            0.000000       0.000000       0.000000      0.000000
# 25%            0.000000       0.000000       0.000000      0.000000
# 50%            0.000000       0.000000       0.000000      0.000000
# 75%            0.000000       1.000000       1.000000      0.000000
# max            1.000000       1.000000       1.000000      1.000000
#
#            Platums       Garums
# count  5782.000000  5782.000000
# mean     56.958138    24.133378
# std       0.029560     0.060266
# min      56.895517    23.985474
# 25%      56.940895    24.095862
# 50%      56.955497    24.135349
# 75%      56.972837    24.173810
# max      57.074366    24.310248

# %%
corr = data.corr()
corr.shape
# Out:
# (18, 18)

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(corr, annot=True, fmt='.2f', annot_kws={'size':16}, cmap='coolwarm')
# Out:
# <Axes: >
