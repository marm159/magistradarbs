# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('dati_fin.csv', sep=';')

# %%
# rindu un kolonu skaits
data.shape
# Out:
# (22631, 18)

# %%
# Datu tipi
data.dtypes
# Out:
# Darījuma summa, EUR                     float64
# Pārdotā zemes kopplatība, m2            float64
# Būvju skaits                              int64
# Būves virszemes stāvu skaits              int64
# Būves kopplatība, m2                    float64
# Būves ekspluatācijas uzsākšanas gads      int64
# Būves fiziskais nolietojums, %            int64
# Telpu grupas platība, m2                float64
# Telpu skaits telpu grupā                  int64
# Istabu skaits dzīvoklī                    int64
# Telpu grupas vidējais stāvs             float64
# Gads                                      int64
# sezona_Pavasaris                          int64
# sezona_Rudens                             int64
# sezona_Vasara                             int64
# sezona_Ziema                              int64
# Platums                                 float64
# Garums                                  float64
# dtype: object

# %%
# Vai ir kādas tukšas vērtības
data.isnull().sum()
# Out:
# Darījuma summa, EUR                     0
# Pārdotā zemes kopplatība, m2            0
# Būvju skaits                            0
# Būves virszemes stāvu skaits            0
# Būves kopplatība, m2                    0
# Būves ekspluatācijas uzsākšanas gads    0
# Būves fiziskais nolietojums, %          0
# Telpu grupas platība, m2                0
# Telpu skaits telpu grupā                0
# Istabu skaits dzīvoklī                  0
# Telpu grupas vidējais stāvs             0
# Gads                                    0
# sezona_Pavasaris                        0
# sezona_Rudens                           0
# sezona_Vasara                           0
# sezona_Ziema                            0
# Platums                                 0
# Garums                                  0
# dtype: int64

# %%
data.describe()
# Out:
#        Darījuma summa, EUR  Pārdotā zemes kopplatība, m2  Būvju skaits  \
# count         22631.000000                  22631.000000  22631.000000
# mean          72542.080825                     59.833328      1.724537
# std           57617.246261                     53.482115      1.562298
# min            1000.000000                      0.000000      1.000000
# 25%           31000.000000                     32.000000      1.000000
# 50%           57000.000000                     49.000000      1.000000
# 75%          101020.000000                     70.940000      2.000000
# max          745000.000000                   1966.680000     22.000000
#
#        Būves virszemes stāvu skaits  Būves kopplatība, m2  \
# count                  22631.000000          22631.000000
# mean                       5.939685           4348.813088
# std                        3.093624           3760.593443
# min                        1.000000             80.400000
# 25%                        4.000000           1673.900000
# 50%                        5.000000           3613.200000
# 75%                        7.000000           5350.400000
# max                       31.000000          34428.100000
#
#        Būves ekspluatācijas uzsākšanas gads  Būves fiziskais nolietojums, %  \
# count                          22631.000000                    22631.000000
# mean                            1962.909770                       25.477973
# std                               45.975504                       19.983991
# min                             1095.000000                        0.000000
# 25%                             1913.000000                        1.000000
# 50%                             1968.000000                       28.000000
# 75%                             2007.000000                       35.000000
# max                             2023.000000                       85.000000
#
#        Telpu grupas platība, m2  Telpu skaits telpu grupā  \
# count              22631.000000              22631.000000
# mean                  55.548213                  5.734523
# std                   28.742911                  2.589801
# min                    8.700000                  1.000000
# 25%                   38.300000                  4.000000
# 50%                   49.900000                  5.000000
# 75%                   66.250000                  7.000000
# max                  434.900000                 26.000000
#
#        Istabu skaits dzīvoklī  Telpu grupas vidējais stāvs          Gads  \
# count            22631.000000                 22631.000000  22631.000000
# mean                 2.184216                     3.415514   2021.448632
# std                  1.030190                     2.291996      1.209734
# min                  1.000000                    -1.000000   2001.000000
# 25%                  1.000000                     2.000000   2021.000000
# 50%                  2.000000                     3.000000   2021.000000
# 75%                  3.000000                     5.000000   2022.000000
# max                 13.000000                    25.500000   2024.000000
#
#        sezona_Pavasaris  sezona_Rudens  sezona_Vasara  sezona_Ziema  \
# count      22631.000000   22631.000000   22631.000000  22631.000000
# mean           0.234501       0.261588       0.251867      0.252044
# std            0.423696       0.439509       0.434095      0.434196
# min            0.000000       0.000000       0.000000      0.000000
# 25%            0.000000       0.000000       0.000000      0.000000
# 50%            0.000000       0.000000       0.000000      0.000000
# 75%            0.000000       1.000000       1.000000      1.000000
# max            1.000000       1.000000       1.000000      1.000000
#
#             Platums        Garums
# count  22631.000000  22631.000000
# mean      56.958558     24.133185
# std        0.028465      0.060567
# min       56.895133     23.989379
# 25%       56.943301     24.098211
# 50%       56.956105     24.133826
# 75%       56.971792     24.173325
# max       57.077635     24.310680

# %%
corr = data.corr()
corr.shape
# Out:
# (18, 18)

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(corr, annot=True, fmt='.2f', annot_kws={'size':16}, cmap='coolwarm')
# Out:
# <Axes: >
