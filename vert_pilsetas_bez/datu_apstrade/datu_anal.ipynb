# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('dati_fin.csv', sep=';')
del_col = ['Darījuma datums']
data = data.drop(columns=del_col)

# %%
# rindu un kolonu skaits
data.shape
# Out:
# (2034, 16)

# %%
# Datu tipi
data.dtypes
# Out:
# Darījuma summa, EUR                     float64
# Būvju skaits                              int64
# Būves virszemes stāvu skaits              int64
# Būves apbūves laukums, m2               float64
# Būves kopplatība, m2                    float64
# Būves būvtilpums, m3                    float64
# Būves ekspluatācijas uzsākšanas gads      int64
# Būves fiziskais nolietojums, %            int64
# Telpu grupas zemākais stāvs               int64
# Telpu grupas augstākais stāvs             int64
# Telpu grupas platība, m2                float64
# Dzīvokļa kopplatība, m2                 float64
# Telpu skaits telpu grupā                  int64
# Istabu skaits dzīvoklī                    int64
# Garums                                  float64
# Platums                                 float64
# dtype: object

# %%
# Vai ir kādas tukšas vērtības
data.isnull().sum()
# Out:
# Darījuma summa, EUR                     0
# Būvju skaits                            0
# Būves virszemes stāvu skaits            0
# Būves apbūves laukums, m2               0
# Būves kopplatība, m2                    0
# Būves būvtilpums, m3                    0
# Būves ekspluatācijas uzsākšanas gads    0
# Būves fiziskais nolietojums, %          0
# Telpu grupas zemākais stāvs             0
# Telpu grupas augstākais stāvs           0
# Telpu grupas platība, m2                0
# Dzīvokļa kopplatība, m2                 0
# Telpu skaits telpu grupā                0
# Istabu skaits dzīvoklī                  0
# Garums                                  0
# Platums                                 0
# dtype: int64

# %%
data.describe()
# Out:
#        Darījuma summa, EUR  Būvju skaits  Būves virszemes stāvu skaits  \
# count          2034.000000   2034.000000                   2034.000000
# mean          15081.393456      1.123402                      4.258112
# std           11729.860804      0.444691                      1.220720
# min            1000.000000      1.000000                      1.000000
# 25%            5525.000000      1.000000                      3.000000
# 50%           11500.000000      1.000000                      5.000000
# 75%           21500.000000      1.000000                      5.000000
# max           73000.000000      6.000000                      9.000000
#
#        Būves apbūves laukums, m2  Būves kopplatība, m2  Būves būvtilpums, m3  \
# count                2034.000000           2034.000000           2034.000000
# mean                  682.385605           2850.186087           9850.963127
# std                   271.102793           1476.808818           5018.296754
# min                   116.600000            133.200000            465.000000
# 25%                   523.100000           1751.300000           6239.000000
# 50%                   672.000000           2907.550000          10466.000000
# 75%                   841.800000           3759.100000          12739.000000
# max                  1667.200000           7479.500000          27156.000000
#
#        Būves ekspluatācijas uzsākšanas gads  Būves fiziskais nolietojums, %  \
# count                           2034.000000                     2034.000000
# mean                            1974.464602                       25.194199
# std                               12.631715                       11.663934
# min                             1870.000000                        0.000000
# 25%                             1969.000000                       15.000000
# 50%                             1976.000000                       25.000000
# 75%                             1983.000000                       30.000000
# max                             2008.000000                       85.000000
#
#        Telpu grupas zemākais stāvs  Telpu grupas augstākais stāvs  \
# count                  2034.000000                    2034.000000
# mean                      2.705506                       2.716323
# std                       1.419525                       1.414443
# min                      -1.000000                      -1.000000
# 25%                       1.000000                       1.000000
# 50%                       3.000000                       3.000000
# 75%                       4.000000                       4.000000
# max                       9.000000                       9.000000
#
#        Telpu grupas platība, m2  Dzīvokļa kopplatība, m2  \
# count               2034.000000              2034.000000
# mean                  48.397345                46.544199
# std                   14.774664                13.520189
# min                   13.200000                13.200000
# 25%                   36.800000                36.000000
# 50%                   46.700000                45.900000
# 75%                   56.275000                54.100000
# max                  124.100000               116.900000
#
#        Telpu skaits telpu grupā  Istabu skaits dzīvoklī       Garums  \
# count               2034.000000             2034.000000  2034.000000
# mean                   6.360374                1.998033    56.901531
# std                    1.794790                0.761207     0.406017
# min                    1.000000                1.000000    56.300000
# 25%                    5.000000                1.000000    56.604167
# 50%                    6.000000                2.000000    56.851111
# 75%                    7.000000                2.000000    57.312500
# max                   13.000000                5.000000    57.863889
#
#            Platums
# count  2034.000000
# mean     24.886368
# std       1.737088
# min      21.166111
# 25%      23.153333
# 50%      25.255278
# 75%      26.716667
# max      27.726944

# %%
corr = data.corr()
corr.shape
# Out:
# (16, 16)

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(corr, annot=True, fmt='.2f', annot_kws={'size':16}, cmap='coolwarm')
# Out:
# <Axes: >
