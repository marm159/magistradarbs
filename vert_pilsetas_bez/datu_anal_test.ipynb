# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('2024_gg.csv', sep=';')

# %%
# rindu un kolonu skaits
data.shape
# Out:
# (544, 17)

# %%
# Datu tipi
data.dtypes
# Out:
# Darījuma summa, EUR                     float64
# Būvju skaits                              int64
# Būves virszemes stāvu skaits              int64
# Būves kopplatība, m2                    float64
# Būves ekspluatācijas uzsākšanas gads      int64
# Būves fiziskais nolietojums, %          float64
# Telpu grupas platība, m2                float64
# Telpu skaits telpu grupā                  int64
# Istabu skaits dzīvoklī                    int64
# Garums                                  float64
# Platums                                 float64
# Telpu grupas vidējais stāvs             float64
# Gads                                      int64
# sezona_Pavasaris                          int64
# sezona_Rudens                             int64
# sezona_Vasara                             int64
# sezona_Ziema                              int64
# dtype: object

# %%
# Vai ir kādas tukšas vērtības
data.isnull().sum()
# Out:
# Darījuma summa, EUR                     0
# Būvju skaits                            0
# Būves virszemes stāvu skaits            0
# Būves kopplatība, m2                    0
# Būves ekspluatācijas uzsākšanas gads    0
# Būves fiziskais nolietojums, %          0
# Telpu grupas platība, m2                0
# Telpu skaits telpu grupā                0
# Istabu skaits dzīvoklī                  0
# Garums                                  0
# Platums                                 0
# Telpu grupas vidējais stāvs             0
# Gads                                    0
# sezona_Pavasaris                        0
# sezona_Rudens                           0
# sezona_Vasara                           0
# sezona_Ziema                            0
# dtype: int64

# %%
data.describe()
# Out:
#        Darījuma summa, EUR  Būvju skaits  Būves virszemes stāvu skaits  \
# count           544.000000    544.000000                    544.000000
# mean          19674.203290      1.139706                      4.158088
# std           14881.043383      0.452906                      1.281979
# min            1000.000000      1.000000                      1.000000
# 25%            8261.250000      1.000000                      3.000000
# 50%           15090.750000      1.000000                      5.000000
# 75%           28000.000000      1.000000                      5.000000
# max           85000.000000      5.000000                      9.000000
#
#        Būves kopplatība, m2  Būves ekspluatācijas uzsākšanas gads  \
# count            544.000000                            544.000000
# mean            2693.085294                           1973.545956
# std             1513.316005                             14.452746
# min              127.200000                           1870.000000
# 25%             1342.100000                           1969.000000
# 50%             2595.100000                           1975.000000
# 75%             3629.200000                           1982.000000
# max             7475.800000                           1994.000000
#
#        Būves fiziskais nolietojums, %  Telpu grupas platība, m2  \
# count                      544.000000                544.000000
# mean                        26.466912                 47.897243
# std                         11.843781                 16.052456
# min                          0.000000                 18.900000
# 25%                         20.000000                 36.250000
# 50%                         28.000000                 46.550000
# 75%                         30.000000                 55.700000
# max                         70.000000                189.600000
#
#        Telpu skaits telpu grupā  Istabu skaits dzīvoklī      Garums  \
# count                544.000000              544.000000  544.000000
# mean                   6.371324                1.977941   56.912546
# std                    1.875004                0.781620    0.394330
# min                    2.000000                1.000000   56.300000
# 25%                    5.000000                1.000000   56.604167
# 50%                    6.000000                2.000000   56.851111
# 75%                    7.000000                2.000000   57.246667
# max                   16.000000                5.000000   57.751667
#
#           Platums  Telpu grupas vidējais stāvs         Gads  sezona_Pavasaris  \
# count  544.000000                   544.000000   544.000000        544.000000
# mean    24.765722                     2.593750  2023.814338          0.244485
# std      1.720660                     1.402916     0.952121          0.430177
# min     21.166111                     0.500000  2012.000000          0.000000
# 25%     23.153333                     1.000000  2024.000000          0.000000
# 50%     25.255278                     2.000000  2024.000000          0.000000
# 75%     26.219444                     4.000000  2024.000000          0.000000
# max     27.726944                     8.000000  2024.000000          1.000000
#
#        sezona_Rudens  sezona_Vasara  sezona_Ziema
# count     544.000000     544.000000    544.000000
# mean        0.268382       0.268382      0.218750
# std         0.443526       0.443526      0.413779
# min         0.000000       0.000000      0.000000
# 25%         0.000000       0.000000      0.000000
# 50%         0.000000       0.000000      0.000000
# 75%         1.000000       1.000000      0.000000
# max         1.000000       1.000000      1.000000

# %%
corr = data.corr()
corr.shape
# Out:
# (17, 17)

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(corr, annot=True, fmt='.2f', annot_kws={'size':16}, cmap='coolwarm')
# Out:
# <Axes: >
