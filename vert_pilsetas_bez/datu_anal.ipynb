# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('dati_gg.csv', sep=';')

# %%
# rindu un kolonu skaits
data.shape
# Out:
# (2034, 17)

# %%
# Datu tipi
data.dtypes
# Out:
# Darījuma summa, EUR                     float64
# Būvju skaits                              int64
# Būves virszemes stāvu skaits              int64
# Būves kopplatība, m2                    float64
# Būves ekspluatācijas uzsākšanas gads      int64
# Būves fiziskais nolietojums, %            int64
# Telpu grupas platība, m2                float64
# Telpu skaits telpu grupā                  int64
# Istabu skaits dzīvoklī                    int64
# Garums                                  float64
# Platums                                 float64
# Telpu grupas vidējais stāvs             float64
# Gads                                      int64
# sezona_Pavasaris                          int64
# sezona_Rudens                             int64
# sezona_Vasara                             int64
# sezona_Ziema                              int64
# dtype: object

# %%
# Vai ir kādas tukšas vērtības
data.isnull().sum()
# Out:
# Darījuma summa, EUR                     0
# Būvju skaits                            0
# Būves virszemes stāvu skaits            0
# Būves kopplatība, m2                    0
# Būves ekspluatācijas uzsākšanas gads    0
# Būves fiziskais nolietojums, %          0
# Telpu grupas platība, m2                0
# Telpu skaits telpu grupā                0
# Istabu skaits dzīvoklī                  0
# Garums                                  0
# Platums                                 0
# Telpu grupas vidējais stāvs             0
# Gads                                    0
# sezona_Pavasaris                        0
# sezona_Rudens                           0
# sezona_Vasara                           0
# sezona_Ziema                            0
# dtype: int64

# %%
data.describe()
# Out:
#        Darījuma summa, EUR  Būvju skaits  Būves virszemes stāvu skaits  \
# count          2034.000000   2034.000000                   2034.000000
# mean          15081.393456      1.123402                      4.258112
# std           11729.860804      0.444691                      1.220720
# min            1000.000000      1.000000                      1.000000
# 25%            5525.000000      1.000000                      3.000000
# 50%           11500.000000      1.000000                      5.000000
# 75%           21500.000000      1.000000                      5.000000
# max           73000.000000      6.000000                      9.000000
#
#        Būves kopplatība, m2  Būves ekspluatācijas uzsākšanas gads  \
# count           2034.000000                           2034.000000
# mean            2850.186087                           1974.464602
# std             1476.808818                             12.631715
# min              133.200000                           1870.000000
# 25%             1751.300000                           1969.000000
# 50%             2907.550000                           1976.000000
# 75%             3759.100000                           1983.000000
# max             7479.500000                           2008.000000
#
#        Būves fiziskais nolietojums, %  Telpu grupas platība, m2  \
# count                     2034.000000               2034.000000
# mean                        25.194199                 48.397345
# std                         11.663934                 14.774664
# min                          0.000000                 13.200000
# 25%                         15.000000                 36.800000
# 50%                         25.000000                 46.700000
# 75%                         30.000000                 56.275000
# max                         85.000000                124.100000
#
#        Telpu skaits telpu grupā  Istabu skaits dzīvoklī       Garums  \
# count               2034.000000             2034.000000  2034.000000
# mean                   6.360374                1.998033    56.901531
# std                    1.794790                0.761207     0.406017
# min                    1.000000                1.000000    56.300000
# 25%                    5.000000                1.000000    56.604167
# 50%                    6.000000                2.000000    56.851111
# 75%                    7.000000                2.000000    57.312500
# max                   13.000000                5.000000    57.863889
#
#            Platums  Telpu grupas vidējais stāvs         Gads  \
# count  2034.000000                  2034.000000  2034.000000
# mean     24.886368                     2.710914  2021.246313
# std       1.737088                     1.415433     1.819661
# min      21.166111                    -1.000000  1998.000000
# 25%      23.153333                     1.000000  2020.000000
# 50%      25.255278                     3.000000  2021.000000
# 75%      26.716667                     4.000000  2022.000000
# max      27.726944                     9.000000  2024.000000
#
#        sezona_Pavasaris  sezona_Rudens  sezona_Vasara  sezona_Ziema
# count       2034.000000    2034.000000    2034.000000   2034.000000
# mean           0.243854       0.240413       0.282203      0.233530
# std            0.429512       0.427439       0.450182      0.423181
# min            0.000000       0.000000       0.000000      0.000000
# 25%            0.000000       0.000000       0.000000      0.000000
# 50%            0.000000       0.000000       0.000000      0.000000
# 75%            0.000000       0.000000       1.000000      0.000000
# max            1.000000       1.000000       1.000000      1.000000

# %%
corr = data.corr()
corr.shape
# Out:
# (17, 17)

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(corr, annot=True, fmt='.2f', annot_kws={'size':16}, cmap='coolwarm')
# Out:
# <Axes: >
