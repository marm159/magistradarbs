# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('dati_fin.csv', sep=';')
del_col = ['Darījuma datums']
data = data.drop(columns=del_col)

# %%
# rindu un kolonu skaits
data.shape
# Out:
# (3512, 16)

# %%
# Datu tipi
data.dtypes
# Out:
# Darījuma summa, EUR                     float64
# Būvju skaits                              int64
# Būves virszemes stāvu skaits              int64
# Būves apbūves laukums, m2               float64
# Būves kopplatība, m2                    float64
# Būves būvtilpums, m3                    float64
# Būves ekspluatācijas uzsākšanas gads      int64
# Būves fiziskais nolietojums, %            int64
# Telpu grupas zemākais stāvs               int64
# Telpu grupas augstākais stāvs             int64
# Telpu grupas platība, m2                float64
# Dzīvokļa kopplatība, m2                 float64
# Telpu skaits telpu grupā                  int64
# Istabu skaits dzīvoklī                    int64
# Garums                                  float64
# Platums                                 float64
# dtype: object

# %%
# Vai ir kādas tukšas vērtības
data.isnull().sum()
# Out:
# Darījuma summa, EUR                     0
# Būvju skaits                            0
# Būves virszemes stāvu skaits            0
# Būves apbūves laukums, m2               0
# Būves kopplatība, m2                    0
# Būves būvtilpums, m3                    0
# Būves ekspluatācijas uzsākšanas gads    0
# Būves fiziskais nolietojums, %          0
# Telpu grupas zemākais stāvs             0
# Telpu grupas augstākais stāvs           0
# Telpu grupas platība, m2                0
# Dzīvokļa kopplatība, m2                 0
# Telpu skaits telpu grupā                0
# Istabu skaits dzīvoklī                  0
# Garums                                  0
# Platums                                 0
# dtype: int64

# %%
data.describe()
# Out:
#        Darījuma summa, EUR  Būvju skaits  Būves virszemes stāvu skaits  \
# count          3512.000000   3512.000000                   3512.000000
# mean          23285.724849      1.127847                      4.984909
# std           18106.224265      0.536239                      1.708307
# min            1000.000000      1.000000                      1.000000
# 25%            9000.000000      1.000000                      5.000000
# 50%           19125.000000      1.000000                      5.000000
# 75%           33537.500000      1.000000                      5.000000
# max          205000.000000      8.000000                     12.000000
#
#        Būves apbūves laukums, m2  Būves kopplatība, m2  Būves būvtilpums, m3  \
# count                3512.000000           3512.000000           3512.000000
# mean                  828.369505           3805.383599          13321.580581
# std                   424.225607           2150.247327           7634.609086
# min                    82.000000            108.700000            404.000000
# 25%                   553.900000           2378.450000           8313.000000
# 50%                   738.700000           3559.600000          12290.000000
# 75%                  1048.600000           4977.000000          16925.000000
# max                  2743.500000          12543.700000          46216.000000
#
#        Būves ekspluatācijas uzsākšanas gads  Būves fiziskais nolietojums, %  \
# count                           3512.000000                     3512.000000
# mean                            1973.301253                       24.457574
# std                               16.209442                       11.246692
# min                             1790.000000                        0.000000
# 25%                             1966.000000                       16.000000
# 50%                             1975.000000                       25.000000
# 75%                             1984.000000                       30.000000
# max                             2007.000000                       75.000000
#
#        Telpu grupas zemākais stāvs  Telpu grupas augstākais stāvs  \
# count                  3512.000000                    3512.000000
# mean                      3.060934                       3.068622
# std                       1.633716                       1.630706
# min                      -1.000000                       1.000000
# 25%                       2.000000                       2.000000
# 50%                       3.000000                       3.000000
# 75%                       4.000000                       4.000000
# max                       9.000000                       9.000000
#
#        Telpu grupas platība, m2  Dzīvokļa kopplatība, m2  \
# count               3512.000000              3512.000000
# mean                  47.381577                45.450911
# std                   15.034110                13.725397
# min                   11.600000                11.600000
# 25%                   36.600000                35.500000
# 50%                   46.300000                45.000000
# 75%                   55.200000                52.300000
# max                  189.400000               189.400000
#
#        Telpu skaits telpu grupā  Istabu skaits dzīvoklī       Garums  \
# count               3512.000000             3512.000000  3512.000000
# mean                   6.279043                1.958144    56.708865
# std                    1.867632                0.792094     0.412950
# min                    1.000000                1.000000    55.875000
# 25%                    5.000000                1.000000    56.506389
# 50%                    6.000000                2.000000    56.511667
# 75%                    7.000000                2.000000    56.818611
# max                   14.000000                5.000000    57.538611
#
#            Platums
# count  3512.000000
# mean     23.898471
# std       2.188471
# min      21.013889
# 25%      21.573333
# 50%      23.713889
# 75%      25.878333
# max      27.330556

# %%
corr = data.corr()
corr.shape
# Out:
# (16, 16)

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(corr, annot=True, fmt='.2f', annot_kws={'size':16}, cmap='coolwarm')
# Out:
# <Axes: >
