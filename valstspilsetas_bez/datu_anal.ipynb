# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('dati_gg.csv', sep=';')

# %%
# rindu un kolonu skaits
data.shape
# Out:
# (3512, 17)

# %%
# Datu tipi
data.dtypes
# Out:
# Darījuma summa, EUR                     float64
# Būvju skaits                              int64
# Būves virszemes stāvu skaits              int64
# Būves kopplatība, m2                    float64
# Būves ekspluatācijas uzsākšanas gads      int64
# Būves fiziskais nolietojums, %            int64
# Telpu grupas platība, m2                float64
# Telpu skaits telpu grupā                  int64
# Istabu skaits dzīvoklī                    int64
# Garums                                  float64
# Platums                                 float64
# Telpu grupas vidējais stāvs             float64
# Gads                                      int64
# sezona_Pavasaris                          int64
# sezona_Rudens                             int64
# sezona_Vasara                             int64
# sezona_Ziema                              int64
# dtype: object

# %%
# Vai ir kādas tukšas vērtības
data.isnull().sum()
# Out:
# Darījuma summa, EUR                     0
# Būvju skaits                            0
# Būves virszemes stāvu skaits            0
# Būves kopplatība, m2                    0
# Būves ekspluatācijas uzsākšanas gads    0
# Būves fiziskais nolietojums, %          0
# Telpu grupas platība, m2                0
# Telpu skaits telpu grupā                0
# Istabu skaits dzīvoklī                  0
# Garums                                  0
# Platums                                 0
# Telpu grupas vidējais stāvs             0
# Gads                                    0
# sezona_Pavasaris                        0
# sezona_Rudens                           0
# sezona_Vasara                           0
# sezona_Ziema                            0
# dtype: int64

# %%
data.describe()
# Out:
#        Darījuma summa, EUR  Būvju skaits  Būves virszemes stāvu skaits  \
# count          3512.000000   3512.000000                   3512.000000
# mean          23285.724849      1.127847                      4.984909
# std           18106.224265      0.536239                      1.708307
# min            1000.000000      1.000000                      1.000000
# 25%            9000.000000      1.000000                      5.000000
# 50%           19125.000000      1.000000                      5.000000
# 75%           33537.500000      1.000000                      5.000000
# max          205000.000000      8.000000                     12.000000
#
#        Būves kopplatība, m2  Būves ekspluatācijas uzsākšanas gads  \
# count           3512.000000                           3512.000000
# mean            3805.383599                           1973.301253
# std             2150.247327                             16.209442
# min              108.700000                           1790.000000
# 25%             2378.450000                           1966.000000
# 50%             3559.600000                           1975.000000
# 75%             4977.000000                           1984.000000
# max            12543.700000                           2007.000000
#
#        Būves fiziskais nolietojums, %  Telpu grupas platība, m2  \
# count                     3512.000000               3512.000000
# mean                        24.457574                 47.381577
# std                         11.246692                 15.034110
# min                          0.000000                 11.600000
# 25%                         16.000000                 36.600000
# 50%                         25.000000                 46.300000
# 75%                         30.000000                 55.200000
# max                         75.000000                189.400000
#
#        Telpu skaits telpu grupā  Istabu skaits dzīvoklī       Garums  \
# count               3512.000000             3512.000000  3512.000000
# mean                   6.279043                1.958144    56.708865
# std                    1.867632                0.792094     0.412950
# min                    1.000000                1.000000    55.875000
# 25%                    5.000000                1.000000    56.506389
# 50%                    6.000000                2.000000    56.511667
# 75%                    7.000000                2.000000    56.818611
# max                   14.000000                5.000000    57.538611
#
#            Platums  Telpu grupas vidējais stāvs         Gads  \
# count  3512.000000                  3512.000000  3512.000000
# mean     23.898471                     3.064778  2021.353075
# std       2.188471                     1.631191     1.528071
# min      21.013889                     0.000000  1998.000000
# 25%      21.573333                     2.000000  2020.000000
# 50%      23.713889                     3.000000  2021.000000
# 75%      25.878333                     4.000000  2022.000000
# max      27.330556                     9.000000  2023.000000
#
#        sezona_Pavasaris  sezona_Rudens  sezona_Vasara  sezona_Ziema
# count       3512.000000    3512.000000    3512.000000   3512.000000
# mean           0.244021       0.261105       0.274203      0.220672
# std            0.429566       0.439299       0.446175      0.414759
# min            0.000000       0.000000       0.000000      0.000000
# 25%            0.000000       0.000000       0.000000      0.000000
# 50%            0.000000       0.000000       0.000000      0.000000
# 75%            0.000000       1.000000       1.000000      0.000000
# max            1.000000       1.000000       1.000000      1.000000

# %%
corr = data.corr()
corr.shape
# Out:
# (17, 17)

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(corr, annot=True, fmt='.2f', annot_kws={'size':16}, cmap='coolwarm')
# Out:
# <Axes: >
