# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('2024_gg.csv', sep=';')

# %%
# rindu un kolonu skaits
data.shape
# Out:
# (814, 17)

# %%
# Datu tipi
data.dtypes
# Out:
# Darījuma summa, EUR                     float64
# Būvju skaits                              int64
# Būves virszemes stāvu skaits              int64
# Būves kopplatība, m2                    float64
# Būves ekspluatācijas uzsākšanas gads      int64
# Būves fiziskais nolietojums, %          float64
# Telpu grupas platība, m2                float64
# Telpu skaits telpu grupā                  int64
# Istabu skaits dzīvoklī                    int64
# Garums                                  float64
# Platums                                 float64
# Telpu grupas vidējais stāvs             float64
# Gads                                      int64
# sezona_Pavasaris                          int64
# sezona_Rudens                             int64
# sezona_Vasara                             int64
# sezona_Ziema                              int64
# dtype: object

# %%
# Vai ir kādas tukšas vērtības
data.isnull().sum()
# Out:
# Darījuma summa, EUR                     0
# Būvju skaits                            0
# Būves virszemes stāvu skaits            0
# Būves kopplatība, m2                    0
# Būves ekspluatācijas uzsākšanas gads    0
# Būves fiziskais nolietojums, %          0
# Telpu grupas platība, m2                0
# Telpu skaits telpu grupā                0
# Istabu skaits dzīvoklī                  0
# Garums                                  0
# Platums                                 0
# Telpu grupas vidējais stāvs             0
# Gads                                    0
# sezona_Pavasaris                        0
# sezona_Rudens                           0
# sezona_Vasara                           0
# sezona_Ziema                            0
# dtype: int64

# %%
data.describe()
# Out:
#        Darījuma summa, EUR  Būvju skaits  Būves virszemes stāvu skaits  \
# count           814.000000    814.000000                    814.000000
# mean          29303.049189      1.108108                      5.095823
# std           21278.228168      0.473773                      1.688732
# min            1000.000000      1.000000                      1.000000
# 25%           13500.000000      1.000000                      5.000000
# 50%           25000.000000      1.000000                      5.000000
# 75%           40150.000000      1.000000                      5.000000
# max          180000.000000      6.000000                     10.000000
#
#        Būves kopplatība, m2  Būves ekspluatācijas uzsākšanas gads  \
# count            814.000000                            814.000000
# mean            3915.311794                           1973.259214
# std             2179.047676                             16.569148
# min              154.000000                           1856.000000
# 25%             2492.625000                           1966.000000
# 50%             3673.700000                           1975.000000
# 75%             4983.800000                           1984.750000
# max            12543.700000                           2007.000000
#
#        Būves fiziskais nolietojums, %  Telpu grupas platība, m2  \
# count                      814.000000                814.000000
# mean                        25.312039                 48.490663
# std                         10.167039                 16.450153
# min                          0.000000                 12.100000
# 25%                         20.000000                 38.000000
# 50%                         27.000000                 46.350000
# 75%                         30.000000                 56.100000
# max                         65.000000                234.600000
#
#        Telpu skaits telpu grupā  Istabu skaits dzīvoklī      Garums  \
# count                814.000000              814.000000  814.000000
# mean                   6.363636                2.008600   56.694339
# std                    1.945874                0.848224    0.407619
# min                    1.000000                1.000000   55.875000
# 25%                    5.000000                1.000000   56.506389
# 50%                    6.000000                2.000000   56.511667
# 75%                    7.000000                2.000000   56.818611
# max                   21.000000                9.000000   57.538611
#
#           Platums  Telpu grupas vidējais stāvs         Gads  sezona_Pavasaris  \
# count  814.000000                   814.000000   814.000000        814.000000
# mean    24.021627                     3.111179  2023.831695          0.253071
# std      2.181751                     1.665136     1.312229          0.435039
# min     21.013889                    -1.000000  2001.000000          0.000000
# 25%     21.573333                     2.000000  2024.000000          0.000000
# 50%     24.605556                     3.000000  2024.000000          0.000000
# 75%     25.878333                     4.000000  2024.000000          1.000000
# max     27.330556                     9.000000  2024.000000          1.000000
#
#        sezona_Rudens  sezona_Vasara  sezona_Ziema
# count     814.000000     814.000000    814.000000
# mean        0.267813       0.278870      0.200246
# std         0.443092       0.448719      0.400430
# min         0.000000       0.000000      0.000000
# 25%         0.000000       0.000000      0.000000
# 50%         0.000000       0.000000      0.000000
# 75%         1.000000       1.000000      0.000000
# max         1.000000       1.000000      1.000000

# %%
corr = data.corr()
corr.shape
# Out:
# (17, 17)

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(corr, annot=True, fmt='.2f', annot_kws={'size':16}, cmap='coolwarm')
# Out:
# <Axes: >
