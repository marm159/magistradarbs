# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('2024_ar.csv', sep=';')
del_col = ['Adreses pieraksts', 'Pilsēta']
data = data.drop(columns=del_col)

# %%
# rindu un kolonu skaits
data.shape
# Out:
# (10889, 17)

# %%
# Datu tipi
data.dtypes
# Out:
# Darījuma summa, EUR                     float64
# Pārdotā zemes kopplatība, m2            float64
# Būvju skaits                              int64
# Būves virszemes stāvu skaits              int64
# Būves apbūves laukums, m2               float64
# Būves kopplatība, m2                    float64
# Būves būvtilpums, m3                    float64
# Būves ekspluatācijas uzsākšanas gads      int64
# Būves fiziskais nolietojums, %          float64
# Telpu grupas zemākais stāvs               int64
# Telpu grupas augstākais stāvs             int64
# Telpu grupas platība, m2                float64
# Dzīvokļa kopplatība, m2                 float64
# Telpu skaits telpu grupā                  int64
# Istabu skaits dzīvoklī                    int64
# Garums                                  float64
# Platums                                 float64
# dtype: object

# %%
# Vai ir kādas tukšas vērtības
data.isnull().sum()
# Out:
# Darījuma summa, EUR                     0
# Pārdotā zemes kopplatība, m2            0
# Būvju skaits                            0
# Būves virszemes stāvu skaits            0
# Būves apbūves laukums, m2               0
# Būves kopplatība, m2                    0
# Būves būvtilpums, m3                    0
# Būves ekspluatācijas uzsākšanas gads    0
# Būves fiziskais nolietojums, %          0
# Telpu grupas zemākais stāvs             0
# Telpu grupas augstākais stāvs           0
# Telpu grupas platība, m2                0
# Dzīvokļa kopplatība, m2                 0
# Telpu skaits telpu grupā                0
# Istabu skaits dzīvoklī                  0
# Garums                                  0
# Platums                                 0
# dtype: int64

# %%
data.describe()
# Out:
#        Darījuma summa, EUR  Pārdotā zemes kopplatība, m2  Būvju skaits  \
# count         1.088900e+04                  10889.000000  10889.000000
# mean          6.019279e+04                     71.305201      1.515291
# std           7.161090e+04                     97.365211      1.297914
# min           1.000000e+00                      0.630000      1.000000
# 25%           1.680000e+04                     34.580000      1.000000
# 50%           3.700000e+04                     51.030000      1.000000
# 75%           7.900000e+04                     76.620000      1.000000
# max           1.450000e+06                   4313.150000     18.000000
#
#        Būves virszemes stāvu skaits  Būves apbūves laukums, m2  \
# count                  10889.000000               10889.000000
# mean                       5.380200                 802.401664
# std                        2.842937                 569.731742
# min                        1.000000                  74.000000
# 25%                        4.000000                 443.400000
# 50%                        5.000000                 690.900000
# 75%                        6.000000                 969.000000
# max                       31.000000                5875.400000
#
#        Būves kopplatība, m2  Būves būvtilpums, m3  \
# count          10889.000000          10889.000000
# mean            3882.458775          13657.939297
# std             3172.589016          11013.412275
# min               80.400000            293.000000
# 25%             1688.700000           6431.000000
# 50%             3409.700000          11809.000000
# 75%             5006.900000          17494.000000
# max            28589.000000          94138.000000
#
#        Būves ekspluatācijas uzsākšanas gads  Būves fiziskais nolietojums, %  \
# count                          10889.000000                    10889.000000
# mean                            1966.334374                       26.843971
# std                               37.936901                       16.897794
# min                             1600.000000                        0.000000
# 25%                             1956.000000                       15.000000
# 50%                             1972.000000                       29.000000
# 75%                             1987.000000                       34.000000
# max                             2024.000000                       80.000000
#
#        Telpu grupas zemākais stāvs  Telpu grupas augstākais stāvs  \
# count                 10889.000000                   10889.000000
# mean                      3.130866                       3.147305
# std                       2.133205                       2.130473
# min                      -1.000000                      -1.000000
# 25%                       2.000000                       2.000000
# 50%                       3.000000                       3.000000
# 75%                       4.000000                       4.000000
# max                      24.000000                      24.000000
#
#        Telpu grupas platība, m2  Dzīvokļa kopplatība, m2  \
# count              10889.000000             10889.000000
# mean                  52.962889                50.458766
# std                   29.835214                27.317364
# min                    7.100000                 7.100000
# 25%                   37.100000                35.400000
# 50%                   48.100000                46.100000
# 75%                   61.700000                59.100000
# max                  767.300000               763.500000
#
#        Telpu skaits telpu grupā  Istabu skaits dzīvoklī        Garums  \
# count              10889.000000            10889.000000  10889.000000
# mean                   5.928735                2.120764     56.797949
# std                    2.448378                1.022532      0.361004
# min                    1.000000                1.000000     55.875000
# 25%                    4.000000                1.000000     56.648333
# 50%                    6.000000                2.000000     56.947500
# 75%                    7.000000                3.000000     56.947500
# max                   46.000000               26.000000     57.751667
#
#             Platums
# count  10889.000000
# mean      24.224928
# std        1.418994
# min       21.013889
# 25%       24.106389
# 50%       24.106389
# 75%       24.186389
# max       27.726944

# %%
corr = data.corr()
corr.shape
# Out:
# (17, 17)

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(corr, annot=True, fmt='.2f', annot_kws={'size':16}, cmap='coolwarm')
# Out:
# <Axes: >
