# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('2024_bez.csv', sep=';')
del_col = ['Adreses pieraksts', 'Pilsēta']
data = data.drop(columns=del_col)

# %%
# rindu un kolonu skaits
data.shape
# Out:
# (5367, 16)

# %%
# Datu tipi
data.dtypes
# Out:
# Darījuma summa, EUR                     float64
# Būvju skaits                              int64
# Būves virszemes stāvu skaits              int64
# Būves apbūves laukums, m2               float64
# Būves kopplatība, m2                    float64
# Būves būvtilpums, m3                    float64
# Būves ekspluatācijas uzsākšanas gads      int64
# Būves fiziskais nolietojums, %          float64
# Telpu grupas zemākais stāvs               int64
# Telpu grupas augstākais stāvs             int64
# Telpu grupas platība, m2                float64
# Dzīvokļa kopplatība, m2                 float64
# Telpu skaits telpu grupā                  int64
# Istabu skaits dzīvoklī                    int64
# Garums                                  float64
# Platums                                 float64
# dtype: object

# %%
# Vai ir kādas tukšas vērtības
data.isnull().sum()
# Out:
# Darījuma summa, EUR                     0
# Būvju skaits                            0
# Būves virszemes stāvu skaits            0
# Būves apbūves laukums, m2               0
# Būves kopplatība, m2                    0
# Būves būvtilpums, m3                    0
# Būves ekspluatācijas uzsākšanas gads    0
# Būves fiziskais nolietojums, %          0
# Telpu grupas zemākais stāvs             0
# Telpu grupas augstākais stāvs           0
# Telpu grupas platība, m2                0
# Dzīvokļa kopplatība, m2                 0
# Telpu skaits telpu grupā                0
# Istabu skaits dzīvoklī                  0
# Garums                                  0
# Platums                                 0
# dtype: int64

# %%
data.describe()
# Out:
#        Darījuma summa, EUR  Būvju skaits  Būves virszemes stāvu skaits  \
# count          5367.000000   5367.000000                   5367.000000
# mean          42026.757982      1.120365                      6.228806
# std           32616.213695      0.591316                      2.800918
# min               9.900000      1.000000                      1.000000
# 25%           21780.000000      1.000000                      5.000000
# 50%           35500.000000      1.000000                      5.000000
# 75%           54000.000000      1.000000                      9.000000
# max          460000.000000     13.000000                     19.000000
#
#        Būves apbūves laukums, m2  Būves kopplatība, m2  Būves būvtilpums, m3  \
# count                5367.000000           5367.000000           5367.000000
# mean                  916.635785           5100.828321          17160.328675
# std                   543.095774           3771.536954          12497.866864
# min                    95.700000            109.300000            384.000000
# 25%                   598.000000           2864.800000           9963.500000
# 50%                   797.500000           4234.400000          14172.000000
# 75%                  1092.100000           6364.000000          21670.000000
# max                  5603.600000          34419.600000         117894.000000
#
#        Būves ekspluatācijas uzsākšanas gads  Būves fiziskais nolietojums, %  \
# count                           5367.000000                     5367.000000
# mean                            1974.747904                       26.119247
# std                               17.004187                       10.170771
# min                             1856.000000                        0.000000
# 25%                             1968.000000                       20.000000
# 50%                             1975.000000                       29.000000
# 75%                             1984.000000                       30.000000
# max                             2022.000000                       80.000000
#
#        Telpu grupas zemākais stāvs  Telpu grupas augstākais stāvs  \
# count                  5367.000000                    5367.000000
# mean                      3.564375                       3.576113
# std                       2.265030                       2.262278
# min                      -1.000000                      -1.000000
# 25%                       2.000000                       2.000000
# 50%                       3.000000                       3.000000
# 75%                       5.000000                       5.000000
# max                      17.000000                      17.000000
#
#        Telpu grupas platība, m2  Dzīvokļa kopplatība, m2  \
# count               5367.000000              5367.000000
# mean                  51.099665                48.477157
# std                   20.914948                18.566461
# min                   11.300000                11.300000
# 25%                   38.500000                36.050000
# 50%                   48.700000                46.900000
# 75%                   60.300000                57.400000
# max                  357.300000               357.300000
#
#        Telpu skaits telpu grupā  Istabu skaits dzīvoklī       Garums  \
# count                5367.00000             5367.000000  5367.000000
# mean                    6.75517                2.053661    56.905531
# std                     2.30874                0.877149     0.224804
# min                     1.00000                1.000000    55.875000
# 25%                     5.00000                1.000000    56.947500
# 50%                     7.00000                2.000000    56.947500
# 75%                     8.00000                3.000000    56.947500
# max                    25.00000               11.000000    57.751667
#
#            Platums
# count  5367.000000
# mean     24.174266
# std       1.040792
# min      21.013889
# 25%      24.106389
# 50%      24.106389
# 75%      24.106389
# max      27.726944

# %%
corr = data.corr()
corr.shape
# Out:
# (16, 16)

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(corr, annot=True, fmt='.2f', annot_kws={'size':16}, cmap='coolwarm')
# Out:
# <Axes: >
