# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('2024_gg.csv', sep=';')

# %%
# rindu un kolonu skaits
data.shape
# Out:
# (2947, 18)

# %%
# Datu tipi
data.dtypes
# Out:
# Darījuma summa, EUR                     float64
# Pārdotā zemes kopplatība, m2            float64
# Būvju skaits                              int64
# Būves virszemes stāvu skaits              int64
# Būves kopplatība, m2                    float64
# Būves ekspluatācijas uzsākšanas gads      int64
# Būves fiziskais nolietojums, %          float64
# Telpu grupas platība, m2                float64
# Telpu skaits telpu grupā                  int64
# Istabu skaits dzīvoklī                    int64
# Garums                                  float64
# Platums                                 float64
# Telpu grupas vidējais stāvs             float64
# Gads                                      int64
# sezona_Pavasaris                          int64
# sezona_Rudens                             int64
# sezona_Vasara                             int64
# sezona_Ziema                              int64
# dtype: object

# %%
# Vai ir kādas tukšas vērtības
data.isnull().sum()
# Out:
# Darījuma summa, EUR                     0
# Pārdotā zemes kopplatība, m2            0
# Būvju skaits                            0
# Būves virszemes stāvu skaits            0
# Būves kopplatība, m2                    0
# Būves ekspluatācijas uzsākšanas gads    0
# Būves fiziskais nolietojums, %          0
# Telpu grupas platība, m2                0
# Telpu skaits telpu grupā                0
# Istabu skaits dzīvoklī                  0
# Garums                                  0
# Platums                                 0
# Telpu grupas vidējais stāvs             0
# Gads                                    0
# sezona_Pavasaris                        0
# sezona_Rudens                           0
# sezona_Vasara                           0
# sezona_Ziema                            0
# dtype: int64

# %%
data.describe()
# Out:
#        Darījuma summa, EUR  Pārdotā zemes kopplatība, m2  Būvju skaits  \
# count          2947.000000                   2947.000000   2947.000000
# mean          24240.898439                     70.001887      1.235494
# std           22399.524320                     87.630673      0.748515
# min            1000.000000                      6.010000      1.000000
# 25%            8800.000000                     35.750000      1.000000
# 50%           17500.000000                     49.790000      1.000000
# 75%           33722.740000                     71.930000      1.000000
# max          220000.000000                   1579.760000      8.000000
#
#        Būves virszemes stāvu skaits  Būves kopplatība, m2  \
# count                   2947.000000           2947.000000
# mean                       4.930098           3590.710214
# std                        1.918184           2130.727187
# min                        1.000000             91.100000
# 25%                        4.000000           2298.500000
# 50%                        5.000000           3447.200000
# 75%                        5.000000           4893.600000
# max                       14.000000          15730.100000
#
#        Būves ekspluatācijas uzsākšanas gads  Būves fiziskais nolietojums, %  \
# count                            2947.00000                     2947.000000
# mean                             1969.10078                       29.515779
# std                                23.23430                       12.166028
# min                              1800.00000                        0.000000
# 25%                              1964.00000                       20.000000
# 50%                              1974.00000                       30.000000
# 75%                              1984.00000                       35.000000
# max                              2024.00000                       75.000000
#
#        Telpu grupas platība, m2  Telpu skaits telpu grupā  \
# count               2947.000000               2947.000000
# mean                  48.459688                  6.223617
# std                   28.961607                  2.318762
# min                   11.200000                  1.000000
# 25%                   36.400000                  5.000000
# 50%                   46.100000                  6.000000
# 75%                   55.300000                  7.000000
# max                  767.300000                 46.000000
#
#        Istabu skaits dzīvoklī       Garums      Platums  \
# count             2947.000000  2947.000000  2947.000000
# mean                 2.013573    56.450427    24.338465
# std                  1.124536     0.492524     2.406080
# min                  1.000000    55.875000    21.013889
# 25%                  1.000000    55.875000    21.573333
# 50%                  2.000000    56.511667    25.425556
# 75%                  2.000000    56.648333    26.535556
# max                 26.000000    57.538611    27.330556
#
#        Telpu grupas vidējais stāvs         Gads  sezona_Pavasaris  \
# count                  2947.000000  2947.000000       2947.000000
# mean                      2.999152  2023.869698          0.243977
# std                       1.762815     0.997615          0.429552
# min                      -1.000000  2001.000000          0.000000
# 25%                       2.000000  2024.000000          0.000000
# 50%                       3.000000  2024.000000          0.000000
# 75%                       4.000000  2024.000000          0.000000
# max                      12.000000  2024.000000          1.000000
#
#        sezona_Rudens  sezona_Vasara  sezona_Ziema
# count    2947.000000    2947.000000   2947.000000
# mean        0.270105       0.277570      0.208347
# std         0.444089       0.447876      0.406196
# min         0.000000       0.000000      0.000000
# 25%         0.000000       0.000000      0.000000
# 50%         0.000000       0.000000      0.000000
# 75%         1.000000       1.000000      0.000000
# max         1.000000       1.000000      1.000000

# %%
corr = data.corr()
corr.shape
# Out:
# (18, 18)

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(corr, annot=True, fmt='.2f', annot_kws={'size':16}, cmap='coolwarm')
# Out:
# <Axes: >
