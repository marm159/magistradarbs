# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('dati_fin.csv', sep=';')
del_col = ['Darījuma datums']
data = data.drop(columns=del_col)

# %%
# rindu un kolonu skaits
data.shape
# Out:
# (11463, 17)

# %%
# Datu tipi
data.dtypes
# Out:
# Darījuma summa, EUR                     float64
# Pārdotā zemes kopplatība, m2            float64
# Būvju skaits                              int64
# Būves virszemes stāvu skaits              int64
# Būves apbūves laukums, m2               float64
# Būves kopplatība, m2                    float64
# Būves būvtilpums, m3                    float64
# Būves ekspluatācijas uzsākšanas gads      int64
# Būves fiziskais nolietojums, %            int64
# Telpu grupas zemākais stāvs               int64
# Telpu grupas augstākais stāvs             int64
# Telpu grupas platība, m2                float64
# Dzīvokļa kopplatība, m2                 float64
# Telpu skaits telpu grupā                  int64
# Istabu skaits dzīvoklī                    int64
# Garums                                  float64
# Platums                                 float64
# dtype: object

# %%
# Vai ir kādas tukšas vērtības
data.isnull().sum()
# Out:
# Darījuma summa, EUR                     0
# Pārdotā zemes kopplatība, m2            0
# Būvju skaits                            0
# Būves virszemes stāvu skaits            0
# Būves apbūves laukums, m2               0
# Būves kopplatība, m2                    0
# Būves būvtilpums, m3                    0
# Būves ekspluatācijas uzsākšanas gads    0
# Būves fiziskais nolietojums, %          0
# Telpu grupas zemākais stāvs             0
# Telpu grupas augstākais stāvs           0
# Telpu grupas platība, m2                0
# Dzīvokļa kopplatība, m2                 0
# Telpu skaits telpu grupā                0
# Istabu skaits dzīvoklī                  0
# Garums                                  0
# Platums                                 0
# dtype: int64

# %%
data.describe()
# Out:
#        Darījuma summa, EUR  Pārdotā zemes kopplatība, m2  Būvju skaits  \
# count         11463.000000                  11463.000000  11463.000000
# mean          19799.654679                     70.530140      1.248800
# std           18959.483401                     90.163254      0.769354
# min            1000.000000                      4.780000      1.000000
# 25%            6590.000000                     35.270000      1.000000
# 50%           13500.000000                     49.620000      1.000000
# 75%           27000.000000                     72.570000      1.000000
# max          180000.000000                   2465.410000     15.000000
#
#        Būves virszemes stāvu skaits  Būves apbūves laukums, m2  \
# count                  11463.000000               11463.000000
# mean                       4.857193                 759.952587
# std                        1.926797                 395.982003
# min                        1.000000                  49.100000
# 25%                        4.000000                 521.800000
# 50%                        5.000000                 697.200000
# 75%                        5.000000                 986.300000
# max                       14.000000                2826.400000
#
#        Būves kopplatība, m2  Būves būvtilpums, m3  \
# count          11463.000000          11463.000000
# mean            3524.349821          12333.067522
# std             2181.485200           7486.811605
# min               63.700000            275.000000
# 25%             2207.300000           8032.000000
# 50%             3395.700000          11588.000000
# 75%             4844.700000          16547.000000
# max            15743.900000          54222.000000
#
#        Būves ekspluatācijas uzsākšanas gads  Būves fiziskais nolietojums, %  \
# count                          11463.000000                    11463.000000
# mean                            1967.787141                       29.011079
# std                               25.206089                       13.146974
# min                             1750.000000                        0.000000
# 25%                             1963.000000                       20.000000
# 50%                             1974.000000                       30.000000
# 75%                             1983.000000                       35.000000
# max                             2020.000000                       75.000000
#
#        Telpu grupas zemākais stāvs  Telpu grupas augstākais stāvs  \
# count                 11463.000000                   11463.000000
# mean                      2.942162                       2.957167
# std                       1.734835                       1.722757
# min                      -1.000000                      -1.000000
# 25%                       2.000000                       2.000000
# 50%                       3.000000                       3.000000
# 75%                       4.000000                       4.000000
# max                      12.000000                      12.000000
#
#        Telpu grupas platība, m2  Dzīvokļa kopplatība, m2  \
# count              11463.000000             11463.000000
# mean                  47.685222                45.937198
# std                   23.307181                22.457963
# min                    8.400000                 8.400000
# 25%                   35.400000                34.500000
# 50%                   45.400000                44.300000
# 75%                   54.900000                52.400000
# max                  767.300000               763.500000
#
#        Telpu skaits telpu grupā  Istabu skaits dzīvoklī        Garums  \
# count              11463.000000            11463.000000  11463.000000
# mean                   6.173428                1.958301     56.472041
# std                    2.154624                0.971235      0.494078
# min                    1.000000                1.000000     55.875000
# 25%                    5.000000                1.000000     55.875000
# 50%                    6.000000                2.000000     56.511667
# 75%                    7.000000                2.000000     56.648333
# max                   46.000000               26.000000     57.538611
#
#             Platums
# count  11463.000000
# mean      24.125802
# std        2.466458
# min       21.013889
# 25%       21.013889
# 50%       24.605556
# 75%       26.535556
# max       27.330556

# %%
corr = data.corr()
corr.shape
# Out:
# (17, 17)

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(corr, annot=True, fmt='.2f', annot_kws={'size':16}, cmap='coolwarm')
# Out:
# <Axes: >
