# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('dati_gg.csv', sep=';')

# %%
# rindu un kolonu skaits
data.shape
# Out:
# (11463, 18)

# %%
# Datu tipi
data.dtypes
# Out:
# Darījuma summa, EUR                     float64
# Pārdotā zemes kopplatība, m2            float64
# Būvju skaits                              int64
# Būves virszemes stāvu skaits              int64
# Būves kopplatība, m2                    float64
# Būves ekspluatācijas uzsākšanas gads      int64
# Būves fiziskais nolietojums, %            int64
# Telpu grupas platība, m2                float64
# Telpu skaits telpu grupā                  int64
# Istabu skaits dzīvoklī                    int64
# Garums                                  float64
# Platums                                 float64
# Telpu grupas vidējais stāvs             float64
# Gads                                      int64
# sezona_Pavasaris                          int64
# sezona_Rudens                             int64
# sezona_Vasara                             int64
# sezona_Ziema                              int64
# dtype: object

# %%
# Vai ir kādas tukšas vērtības
data.isnull().sum()
# Out:
# Darījuma summa, EUR                     0
# Pārdotā zemes kopplatība, m2            0
# Būvju skaits                            0
# Būves virszemes stāvu skaits            0
# Būves kopplatība, m2                    0
# Būves ekspluatācijas uzsākšanas gads    0
# Būves fiziskais nolietojums, %          0
# Telpu grupas platība, m2                0
# Telpu skaits telpu grupā                0
# Istabu skaits dzīvoklī                  0
# Garums                                  0
# Platums                                 0
# Telpu grupas vidējais stāvs             0
# Gads                                    0
# sezona_Pavasaris                        0
# sezona_Rudens                           0
# sezona_Vasara                           0
# sezona_Ziema                            0
# dtype: int64

# %%
data.describe()
# Out:
#        Darījuma summa, EUR  Pārdotā zemes kopplatība, m2  Būvju skaits  \
# count         11463.000000                  11463.000000  11463.000000
# mean          19799.654679                     70.530140      1.248800
# std           18959.483401                     90.163254      0.769354
# min            1000.000000                      4.780000      1.000000
# 25%            6590.000000                     35.270000      1.000000
# 50%           13500.000000                     49.620000      1.000000
# 75%           27000.000000                     72.570000      1.000000
# max          180000.000000                   2465.410000     15.000000
#
#        Būves virszemes stāvu skaits  Būves kopplatība, m2  \
# count                  11463.000000          11463.000000
# mean                       4.857193           3524.349821
# std                        1.926797           2181.485200
# min                        1.000000             63.700000
# 25%                        4.000000           2207.300000
# 50%                        5.000000           3395.700000
# 75%                        5.000000           4844.700000
# max                       14.000000          15743.900000
#
#        Būves ekspluatācijas uzsākšanas gads  Būves fiziskais nolietojums, %  \
# count                          11463.000000                    11463.000000
# mean                            1967.787141                       29.011079
# std                               25.206089                       13.146974
# min                             1750.000000                        0.000000
# 25%                             1963.000000                       20.000000
# 50%                             1974.000000                       30.000000
# 75%                             1983.000000                       35.000000
# max                             2020.000000                       75.000000
#
#        Telpu grupas platība, m2  Telpu skaits telpu grupā  \
# count              11463.000000              11463.000000
# mean                  47.685222                  6.173428
# std                   23.307181                  2.154624
# min                    8.400000                  1.000000
# 25%                   35.400000                  5.000000
# 50%                   45.400000                  6.000000
# 75%                   54.900000                  7.000000
# max                  767.300000                 46.000000
#
#        Istabu skaits dzīvoklī        Garums       Platums  \
# count            11463.000000  11463.000000  11463.000000
# mean                 1.958301     56.472041     24.125802
# std                  0.971235      0.494078      2.466458
# min                  1.000000     55.875000     21.013889
# 25%                  1.000000     55.875000     21.013889
# 50%                  2.000000     56.511667     24.605556
# 75%                  2.000000     56.648333     26.535556
# max                 26.000000     57.538611     27.330556
#
#        Telpu grupas vidējais stāvs          Gads  sezona_Pavasaris  \
# count                 11463.000000  11463.000000      11463.000000
# mean                      2.949664   2021.345285          0.229608
# std                       1.726765      1.595977          0.420599
# min                      -1.000000   1999.000000          0.000000
# 25%                       2.000000   2020.000000          0.000000
# 50%                       3.000000   2021.000000          0.000000
# 75%                       4.000000   2022.000000          0.000000
# max                      12.000000   2024.000000          1.000000
#
#        sezona_Rudens  sezona_Vasara  sezona_Ziema
# count   11463.000000   11463.000000  11463.000000
# mean        0.250109       0.287098      0.233185
# std         0.433095       0.452427      0.422877
# min         0.000000       0.000000      0.000000
# 25%         0.000000       0.000000      0.000000
# 50%         0.000000       0.000000      0.000000
# 75%         1.000000       1.000000      0.000000
# max         1.000000       1.000000      1.000000

# %%
corr = data.corr()
corr.shape
# Out:
# (18, 18)

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(corr, annot=True, fmt='.2f', annot_kws={'size':16}, cmap='coolwarm')
# Out:
# <Axes: >
