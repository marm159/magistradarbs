# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('dati_fil.csv', sep=';')
del_col = ['Adreses pieraksts', 'Darījuma datums']
data = data.drop(columns=del_col)

# %%
# rindu un kolonu skaits
data.shape
# Out:
# (13574, 14)

# %%
# Datu tipi
data.dtypes
# Out:
# Darījuma summa, EUR                     float64
# Būvju skaits                              int64
# Būves virszemes stāvu skaits              int64
# Būves apbūves laukums, m2               float64
# Būves kopplatība, m2                    float64
# Būves būvtilpums, m3                    float64
# Būves ekspluatācijas uzsākšanas gads      int64
# Būves fiziskais nolietojums, %            int64
# Telpu grupas zemākais stāvs               int64
# Telpu grupas augstākais stāvs             int64
# Telpu grupas platība, m2                float64
# Dzīvokļa kopplatība, m2                 float64
# Telpu skaits telpu grupā                  int64
# Istabu skaits dzīvoklī                    int64
# dtype: object

# %%
# Vai ir kādas tukšas vērtības
data.isnull().sum()
# Out:
# Darījuma summa, EUR                     0
# Būvju skaits                            0
# Būves virszemes stāvu skaits            0
# Būves apbūves laukums, m2               0
# Būves kopplatība, m2                    0
# Būves būvtilpums, m3                    0
# Būves ekspluatācijas uzsākšanas gads    0
# Būves fiziskais nolietojums, %          0
# Telpu grupas zemākais stāvs             0
# Telpu grupas augstākais stāvs           0
# Telpu grupas platība, m2                0
# Dzīvokļa kopplatība, m2                 0
# Telpu skaits telpu grupā                0
# Istabu skaits dzīvoklī                  0
# dtype: int64

# %%
data.describe()
# Out:
#        Darījuma summa, EUR  Būvju skaits  Būves virszemes stāvu skaits  \
# count         13574.000000  13574.000000                  13574.000000
# mean          45999.660441      1.131059                      6.826065
# std           27610.298618      0.657284                      2.901643
# min            1000.000000      1.000000                      1.000000
# 25%           28500.000000      1.000000                      5.000000
# 50%           41000.000000      1.000000                      5.000000
# 75%           58000.000000      1.000000                      9.000000
# max          382000.000000     13.000000                     19.000000
#
#        Būves apbūves laukums, m2  Būves kopplatība, m2  Būves būvtilpums, m3  \
# count               13574.000000          13574.000000          13574.000000
# mean                  977.017761           5762.121048          19165.268823
# std                   636.866414           4018.647170          13410.569356
# min                    64.700000            105.500000            394.000000
# 25%                   617.500000           3518.300000          11053.000000
# 50%                   834.400000           4875.300000          15934.000000
# 75%                  1162.300000           7207.375000          23430.250000
# max                  5603.600000          34428.100000         117894.000000
#
#        Būves ekspluatācijas uzsākšanas gads  Būves fiziskais nolietojums, %  \
# count                          13574.000000                    13574.000000
# mean                            1974.867541                       25.288272
# std                               16.783503                       10.965204
# min                             1850.000000                        0.000000
# 25%                             1968.000000                       20.000000
# 50%                             1975.000000                       28.000000
# 75%                             1984.000000                       30.000000
# max                             2022.000000                       80.000000
#
#        Telpu grupas zemākais stāvs  Telpu grupas augstākais stāvs  \
# count                 13574.000000                   13574.000000
# mean                      3.821644                       3.828054
# std                       2.438051                       2.438406
# min                      -1.000000                      -1.000000
# 25%                       2.000000                       2.000000
# 50%                       3.000000                       3.000000
# 75%                       5.000000                       5.000000
# max                      18.000000                      18.000000
#
#        Telpu grupas platība, m2  Dzīvokļa kopplatība, m2  \
# count              13574.000000             13574.000000
# mean                  51.681840                49.024842
# std                   19.791226                17.620999
# min                    7.400000                 7.400000
# 25%                   39.000000                36.200000
# 50%                   49.600000                47.800000
# 75%                   61.400000                59.200000
# max                  319.900000               267.600000
#
#        Telpu skaits telpu grupā  Istabu skaits dzīvoklī
# count              13574.000000            13574.000000
# mean                   7.005673                2.093856
# std                    2.388739                0.877632
# min                    1.000000                1.000000
# 25%                    5.000000                1.000000
# 50%                    7.000000                2.000000
# 75%                    8.000000                3.000000
# max                   21.000000                7.000000

# %%
corr = data.corr()
corr.shape
# Out:
# (14, 14)

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(corr, annot=True, fmt='.2f', annot_kws={'size':16}, cmap='coolwarm')
# Out:
# <Axes: >
