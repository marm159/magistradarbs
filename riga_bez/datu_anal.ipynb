# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('dati_fin.csv', sep=';')

# %%
# rindu un kolonu skaits
data.shape
# Out:
# (13574, 17)

# %%
# Datu tipi
data.dtypes
# Out:
# Darījuma summa, EUR                     float64
# Būvju skaits                              int64
# Būves virszemes stāvu skaits              int64
# Būves kopplatība, m2                    float64
# Būves ekspluatācijas uzsākšanas gads      int64
# Būves fiziskais nolietojums, %            int64
# Telpu grupas platība, m2                float64
# Telpu skaits telpu grupā                  int64
# Istabu skaits dzīvoklī                    int64
# Telpu grupas vidējais stāvs             float64
# Gads                                      int64
# sezona_Pavasaris                          int64
# sezona_Rudens                             int64
# sezona_Vasara                             int64
# sezona_Ziema                              int64
# Platums                                 float64
# Garums                                  float64
# dtype: object

# %%
# Vai ir kādas tukšas vērtības
data.isnull().sum()
# Out:
# Darījuma summa, EUR                     0
# Būvju skaits                            0
# Būves virszemes stāvu skaits            0
# Būves kopplatība, m2                    0
# Būves ekspluatācijas uzsākšanas gads    0
# Būves fiziskais nolietojums, %          0
# Telpu grupas platība, m2                0
# Telpu skaits telpu grupā                0
# Istabu skaits dzīvoklī                  0
# Telpu grupas vidējais stāvs             0
# Gads                                    0
# sezona_Pavasaris                        0
# sezona_Rudens                           0
# sezona_Vasara                           0
# sezona_Ziema                            0
# Platums                                 0
# Garums                                  0
# dtype: int64

# %%
data.describe()
# Out:
#        Darījuma summa, EUR  Būvju skaits  Būves virszemes stāvu skaits  \
# count         13574.000000  13574.000000                  13574.000000
# mean          45999.660441      1.131059                      6.826065
# std           27610.298618      0.657284                      2.901643
# min            1000.000000      1.000000                      1.000000
# 25%           28500.000000      1.000000                      5.000000
# 50%           41000.000000      1.000000                      5.000000
# 75%           58000.000000      1.000000                      9.000000
# max          382000.000000     13.000000                     19.000000
#
#        Būves kopplatība, m2  Būves ekspluatācijas uzsākšanas gads  \
# count          13574.000000                          13574.000000
# mean            5762.121048                           1974.867541
# std             4018.647170                             16.783503
# min              105.500000                           1850.000000
# 25%             3518.300000                           1968.000000
# 50%             4875.300000                           1975.000000
# 75%             7207.375000                           1984.000000
# max            34428.100000                           2022.000000
#
#        Būves fiziskais nolietojums, %  Telpu grupas platība, m2  \
# count                    13574.000000              13574.000000
# mean                        25.288272                 51.681840
# std                         10.965204                 19.791226
# min                          0.000000                  7.400000
# 25%                         20.000000                 39.000000
# 50%                         28.000000                 49.600000
# 75%                         30.000000                 61.400000
# max                         80.000000                319.900000
#
#        Telpu skaits telpu grupā  Istabu skaits dzīvoklī  \
# count              13574.000000            13574.000000
# mean                   7.005673                2.093856
# std                    2.388739                0.877632
# min                    1.000000                1.000000
# 25%                    5.000000                1.000000
# 50%                    7.000000                2.000000
# 75%                    8.000000                3.000000
# max                   21.000000                7.000000
#
#        Telpu grupas vidējais stāvs          Gads  sezona_Pavasaris  \
# count                 13574.000000  13574.000000      13574.000000
# mean                      3.824849   2021.481730          0.235229
# std                       2.437751      1.303469          0.424158
# min                      -1.000000   1998.000000          0.000000
# 25%                       2.000000   2021.000000          0.000000
# 50%                       3.000000   2022.000000          0.000000
# 75%                       5.000000   2023.000000          0.000000
# max                      18.000000   2024.000000          1.000000
#
#        sezona_Rudens  sezona_Vasara  sezona_Ziema       Platums        Garums
# count   13574.000000   13574.000000  13574.000000  13574.000000  13574.000000
# mean        0.264845       0.265287      0.234640     56.955893     24.135710
# std         0.441267       0.441502      0.423789      0.032314      0.073913
# min         0.000000       0.000000      0.000000     56.895868     23.990678
# 25%         0.000000       0.000000      0.000000     56.937686     24.067658
# 50%         0.000000       0.000000      0.000000     56.957204     24.170316
# 75%         1.000000       1.000000      0.000000     56.967151     24.191779
# max         1.000000       1.000000      1.000000     57.074026     24.309994

# %%
corr = data.corr()
corr.shape
# Out:
# (17, 17)

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(corr, annot=True, fmt='.2f', annot_kws={'size':16}, cmap='coolwarm')
# Out:
# <Axes: >
