# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('2024_fin.csv', sep=';')

# %%
# rindu un kolonu skaits
data.shape
# Out:
# (3693, 17)

# %%
# Datu tipi
data.dtypes
# Out:
# Darījuma summa, EUR                     float64
# Būvju skaits                              int64
# Būves virszemes stāvu skaits              int64
# Būves kopplatība, m2                    float64
# Būves ekspluatācijas uzsākšanas gads      int64
# Būves fiziskais nolietojums, %          float64
# Telpu grupas platība, m2                float64
# Telpu skaits telpu grupā                  int64
# Istabu skaits dzīvoklī                    int64
# Telpu grupas vidējais stāvs             float64
# Gads                                      int64
# sezona_Pavasaris                          int64
# sezona_Rudens                             int64
# sezona_Vasara                             int64
# sezona_Ziema                              int64
# Platums                                 float64
# Garums                                  float64
# dtype: object

# %%
# Vai ir kādas tukšas vērtības
data.isnull().sum()
# Out:
# Darījuma summa, EUR                     0
# Būvju skaits                            0
# Būves virszemes stāvu skaits            0
# Būves kopplatība, m2                    0
# Būves ekspluatācijas uzsākšanas gads    0
# Būves fiziskais nolietojums, %          0
# Telpu grupas platība, m2                0
# Telpu skaits telpu grupā                0
# Istabu skaits dzīvoklī                  0
# Telpu grupas vidējais stāvs             0
# Gads                                    0
# sezona_Pavasaris                        0
# sezona_Rudens                           0
# sezona_Vasara                           0
# sezona_Ziema                            0
# Platums                                 0
# Garums                                  0
# dtype: int64

# %%
data.describe()
# Out:
#        Darījuma summa, EUR  Būvju skaits  Būves virszemes stāvu skaits  \
# count          3693.000000   3693.000000                   3693.000000
# mean          46557.911657      1.118061                      6.906851
# std           30437.201060      0.632397                      2.943581
# min            1500.000000      1.000000                      1.000000
# 25%           29000.000000      1.000000                      5.000000
# 50%           40000.000000      1.000000                      5.000000
# 75%           57000.000000      1.000000                      9.000000
# max          350000.000000     13.000000                     19.000000
#
#        Būves kopplatība, m2  Būves ekspluatācijas uzsākšanas gads  \
# count           3693.000000                           3693.000000
# mean            5817.810127                           1975.282426
# std             4110.599057                             16.064641
# min              109.300000                           1870.000000
# 25%             3550.900000                           1968.000000
# 50%             4862.800000                           1975.000000
# 75%             7153.800000                           1984.000000
# max            34419.600000                           2022.000000
#
#        Būves fiziskais nolietojums, %  Telpu grupas platība, m2  \
# count                     3693.000000               3693.000000
# mean                        26.311129                 51.478771
# std                          9.671774                 21.001622
# min                          0.000000                 11.300000
# 25%                         20.000000                 38.700000
# 50%                         30.000000                 49.000000
# 75%                         30.000000                 60.700000
# max                         80.000000                295.600000
#
#        Telpu skaits telpu grupā  Istabu skaits dzīvoklī  \
# count               3693.000000             3693.000000
# mean                   6.911454                2.060926
# std                    2.398991                0.892258
# min                    1.000000                1.000000
# 25%                    5.000000                1.000000
# 50%                    7.000000                2.000000
# 75%                    8.000000                3.000000
# max                   25.000000               11.000000
#
#        Telpu grupas vidējais stāvs         Gads  sezona_Pavasaris  \
# count                  3693.000000  3693.000000       3693.000000
# mean                      3.883428  2023.947197          0.231519
# std                       2.447336     0.616824          0.421860
# min                      -1.000000  1998.000000          0.000000
# 25%                       2.000000  2024.000000          0.000000
# 50%                       4.000000  2024.000000          0.000000
# 75%                       5.000000  2024.000000          0.000000
# max                      17.000000  2024.000000          1.000000
#
#        sezona_Rudens  sezona_Vasara  sezona_Ziema      Platums       Garums
# count    3693.000000    3693.000000   3693.000000  3693.000000  3693.000000
# mean        0.285134       0.274574      0.208773    56.955615    24.136190
# std         0.451539       0.446360      0.406487     0.031812     0.073836
# min         0.000000       0.000000      0.000000    56.895868    23.990678
# 25%         0.000000       0.000000      0.000000    56.937868    24.065601
# 50%         0.000000       0.000000      0.000000    56.957648    24.171329
# 75%         1.000000       1.000000      0.000000    56.967063    24.191779
# max         1.000000       1.000000      1.000000    57.068401    24.304546

# %%
corr = data.corr()
corr.shape
# Out:
# (17, 17)

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(corr, annot=True, fmt='.2f', annot_kws={'size':16}, cmap='coolwarm')
# Out:
# <Axes: >
