# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('dati_fin.csv', sep=';')

# %%
# rindu un kolonu skaits
data.shape
# Out:
# (735, 16)

# %%
# Datu tipi
data.dtypes
# Out:
# Darījuma summa, EUR                     float64
# Būvju skaits                              int64
# Būves virszemes stāvu skaits              int64
# Būves apbūves laukums, m2               float64
# Būves kopplatība, m2                    float64
# Būves būvtilpums, m3                    float64
# Būves ekspluatācijas uzsākšanas gads      int64
# Būves fiziskais nolietojums, %            int64
# Telpu grupas zemākais stāvs               int64
# Telpu grupas augstākais stāvs             int64
# Telpu grupas platība, m2                float64
# Dzīvokļa kopplatība, m2                 float64
# Telpu skaits telpu grupā                  int64
# Istabu skaits dzīvoklī                    int64
# Garums                                  float64
# Platums                                 float64
# dtype: object

# %%
# Vai ir kādas tukšas vērtības
data.isnull().sum()
# Out:
# Darījuma summa, EUR                     0
# Būvju skaits                            0
# Būves virszemes stāvu skaits            0
# Būves apbūves laukums, m2               0
# Būves kopplatība, m2                    0
# Būves būvtilpums, m3                    0
# Būves ekspluatācijas uzsākšanas gads    0
# Būves fiziskais nolietojums, %          0
# Telpu grupas zemākais stāvs             0
# Telpu grupas augstākais stāvs           0
# Telpu grupas platība, m2                0
# Dzīvokļa kopplatība, m2                 0
# Telpu skaits telpu grupā                0
# Istabu skaits dzīvoklī                  0
# Garums                                  0
# Platums                                 0
# dtype: int64

# %%
data.describe()
# Out:
#        Darījuma summa, EUR  Būvju skaits  Būves virszemes stāvu skaits  \
# count           735.000000    735.000000                    735.000000
# mean          47421.551333      1.048980                      4.420408
# std           40164.216759      0.281676                      1.811669
# min            1000.000000      1.000000                      1.000000
# 25%           18000.000000      1.000000                      3.000000
# 50%           34600.000000      1.000000                      4.000000
# 75%           65250.000000      1.000000                      5.000000
# max          283000.000000      5.000000                     10.000000
#
#        Būves apbūves laukums, m2  Būves kopplatība, m2  Būves būvtilpums, m3  \
# count                 735.000000            735.000000            735.000000
# mean                  920.422449           3544.825714          12404.835374
# std                   556.069427           2081.776946           7482.880849
# min                    95.000000            114.600000            421.000000
# 25%                   515.300000           1841.800000           6673.000000
# 50%                   842.900000           3500.400000          11306.000000
# 75%                  1123.000000           4896.300000          16282.000000
# max                  2771.000000           9183.700000          31403.000000
#
#        Būves ekspluatācijas uzsākšanas gads  Būves fiziskais nolietojums, %  \
# count                            735.000000                      735.000000
# mean                            1984.243537                       21.012245
# std                               17.802941                       11.517366
# min                             1860.000000                        0.000000
# 25%                             1977.000000                       14.000000
# 50%                             1981.000000                       20.000000
# 75%                             1996.000000                       30.000000
# max                             2011.000000                       75.000000
#
#        Telpu grupas zemākais stāvs  Telpu grupas augstākais stāvs  \
# count                   735.000000                     735.000000
# mean                      2.668027                       2.688435
# std                       1.596573                       1.591724
# min                       1.000000                       1.000000
# 25%                       1.000000                       1.000000
# 50%                       2.000000                       2.000000
# 75%                       4.000000                       4.000000
# max                       9.000000                       9.000000
#
#        Telpu grupas platība, m2  Dzīvokļa kopplatība, m2  \
# count                735.000000               735.000000
# mean                  57.208707                53.528027
# std                   24.507667                21.944893
# min                    9.400000                 9.400000
# 25%                   42.500000                37.650000
# 50%                   53.800000                50.600000
# 75%                   67.000000                62.000000
# max                  227.300000               219.800000
#
#        Telpu skaits telpu grupā  Istabu skaits dzīvoklī      Garums  \
# count                735.000000              735.000000  735.000000
# mean                   6.797279                2.163265   56.966268
# std                    2.215500                0.917888    0.180098
# min                    1.000000                1.000000   56.723056
# 25%                    5.000000                1.000000   56.787222
# 50%                    7.000000                2.000000   56.900833
# 75%                    8.000000                3.000000   57.155000
# max                   16.000000                5.000000   57.261944
#
#           Platums
# count  735.000000
# mean    24.499787
# std      0.351317
# min     23.941944
# 25%     24.047778
# 50%     24.546389
# 75%     24.857778
# max     24.857778

# %%
corr = data.corr()
corr.shape
# Out:
# (16, 16)

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(corr, annot=True, fmt='.2f', annot_kws={'size':16}, cmap='coolwarm')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(7, 5))
sns.histplot(data=data, x='Darījuma summa, EUR', kde=True)
plt.ylabel('Skaits')
plt.show()

# %%
# Pielieoto logaritmisko tranformaciju
data['Darījuma summa, EUR'] = np.log1p(data['Darījuma summa, EUR'])

# %%
plt.figure(figsize=(7, 4))
sns.histplot(data=data, x='Darījuma summa, EUR', kde=True)
plt.ylabel('Skaits')
plt.show()
