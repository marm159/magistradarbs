# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('2024_fin.csv', sep=';')

# %%
# rindu un kolonu skaits
data.shape
# Out:
# (188, 16)

# %%
# Datu tipi
data.dtypes
# Out:
# Darījuma summa, EUR                     float64
# Būvju skaits                              int64
# Būves virszemes stāvu skaits              int64
# Būves apbūves laukums, m2               float64
# Būves kopplatība, m2                    float64
# Būves būvtilpums, m3                    float64
# Būves ekspluatācijas uzsākšanas gads      int64
# Būves fiziskais nolietojums, %          float64
# Telpu grupas zemākais stāvs               int64
# Telpu grupas augstākais stāvs             int64
# Telpu grupas platība, m2                float64
# Dzīvokļa kopplatība, m2                 float64
# Telpu skaits telpu grupā                  int64
# Istabu skaits dzīvoklī                    int64
# Garums                                  float64
# Platums                                 float64
# dtype: object

# %%
# Vai ir kādas tukšas vērtības
data.isnull().sum()
# Out:
# Darījuma summa, EUR                     0
# Būvju skaits                            0
# Būves virszemes stāvu skaits            0
# Būves apbūves laukums, m2               0
# Būves kopplatība, m2                    0
# Būves būvtilpums, m3                    0
# Būves ekspluatācijas uzsākšanas gads    0
# Būves fiziskais nolietojums, %          0
# Telpu grupas zemākais stāvs             0
# Telpu grupas augstākais stāvs           0
# Telpu grupas platība, m2                0
# Dzīvokļa kopplatība, m2                 0
# Telpu skaits telpu grupā                0
# Istabu skaits dzīvoklī                  0
# Garums                                  0
# Platums                                 0
# dtype: int64

# %%
data.describe()
# Out:
#        Darījuma summa, EUR  Būvju skaits  Būves virszemes stāvu skaits  \
# count           188.000000    188.000000                    188.000000
# mean          60068.567447      1.069149                      4.319149
# std           48428.129722      0.311122                      1.556169
# min            2739.000000      1.000000                      2.000000
# 25%           23375.000000      1.000000                      3.000000
# 50%           42750.000000      1.000000                      4.000000
# 75%           85000.000000      1.000000                      5.000000
# max          284000.000000      4.000000                     10.000000
#
#        Būves apbūves laukums, m2  Būves kopplatība, m2  Būves būvtilpums, m3  \
# count                 188.000000            188.000000            188.000000
# mean                  990.662234           3689.496277          12860.441489
# std                   611.292536           2194.629417           7832.479729
# min                    95.700000            138.200000            605.000000
# 25%                   549.400000           1966.025000           6989.000000
# 50%                   868.750000           3402.100000          11270.000000
# 75%                  1175.000000           5360.500000          18611.000000
# max                  2771.000000           9183.300000          31403.000000
#
#        Būves ekspluatācijas uzsākšanas gads  Būves fiziskais nolietojums, %  \
# count                            188.000000                      188.000000
# mean                            1983.090426                       22.994681
# std                               23.885809                       12.063334
# min                             1860.000000                        0.000000
# 25%                             1976.000000                       14.000000
# 50%                             1983.000000                       20.000000
# 75%                             2006.000000                       30.000000
# max                             2011.000000                       60.000000
#
#        Telpu grupas zemākais stāvs  Telpu grupas augstākais stāvs  \
# count                   188.000000                     188.000000
# mean                      2.585106                       2.601064
# std                       1.454549                       1.449838
# min                       1.000000                       1.000000
# 25%                       1.000000                       1.000000
# 50%                       2.000000                       2.000000
# 75%                       3.000000                       3.250000
# max                       8.000000                       8.000000
#
#        Telpu grupas platība, m2  Dzīvokļa kopplatība, m2  \
# count                188.000000               188.000000
# mean                  59.277128                54.996277
# std                   28.494008                23.509714
# min                   22.600000                22.600000
# 25%                   42.950000                38.775000
# 50%                   54.200000                51.050000
# 75%                   69.725000                63.825000
# max                  222.600000               215.100000
#
#        Telpu skaits telpu grupā  Istabu skaits dzīvoklī      Garums  \
# count                188.000000              188.000000  188.000000
# mean                   6.696809                2.207447   56.967324
# std                    2.360230                0.910161    0.167984
# min                    1.000000                1.000000   56.723056
# 25%                    5.000000                2.000000   56.820972
# 50%                    7.000000                2.000000   56.900833
# 75%                    8.000000                3.000000   57.155000
# max                   13.000000                4.000000   57.261944
#
#           Platums
# count  188.000000
# mean    24.484607
# std      0.355981
# min     23.941944
# 25%     24.047778
# 50%     24.546389
# 75%     24.857778
# max     24.857778

# %%
corr = data.corr()
corr.shape
# Out:
# (16, 16)

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(corr, annot=True, fmt='.2f', annot_kws={'size':16}, cmap='coolwarm')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(7, 5))
sns.histplot(data=data, x='Darījuma summa, EUR', kde=True)
plt.ylabel('Skaits')
plt.show()

# %%
# Pielieoto logaritmisko tranformaciju
data['Darījuma summa, EUR'] = np.log1p(data['Darījuma summa, EUR'])

# %%
plt.figure(figsize=(7, 4))
sns.histplot(data=data, x='Darījuma summa, EUR', kde=True)
plt.ylabel('Skaits')
plt.show()
