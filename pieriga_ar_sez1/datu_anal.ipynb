# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('dati_gg.csv', sep=';')

# %%
# rindu un kolonu skaits
data.shape
# Out:
# (2628, 17)

# %%
# Datu tipi
data.dtypes
# Out:
# Darījuma summa, EUR                     float64
# Pārdotā zemes kopplatība, m2            float64
# Būvju skaits                              int64
# Būves virszemes stāvu skaits              int64
# Būves apbūves laukums, m2               float64
# Būves kopplatība, m2                    float64
# Būves būvtilpums, m3                    float64
# Būves ekspluatācijas uzsākšanas gads      int64
# Būves fiziskais nolietojums, %            int64
# Telpu grupas zemākais stāvs               int64
# Telpu grupas augstākais stāvs             int64
# Telpu grupas platība, m2                float64
# Dzīvokļa kopplatība, m2                 float64
# Telpu skaits telpu grupā                  int64
# Istabu skaits dzīvoklī                    int64
# Garums                                  float64
# Platums                                 float64
# dtype: object

# %%
# Vai ir kādas tukšas vērtības
data.isnull().sum()
# Out:
# Darījuma summa, EUR                     0
# Pārdotā zemes kopplatība, m2            0
# Būvju skaits                            0
# Būves virszemes stāvu skaits            0
# Būves apbūves laukums, m2               0
# Būves kopplatība, m2                    0
# Būves būvtilpums, m3                    0
# Būves ekspluatācijas uzsākšanas gads    0
# Būves fiziskais nolietojums, %          0
# Telpu grupas zemākais stāvs             0
# Telpu grupas augstākais stāvs           0
# Telpu grupas platība, m2                0
# Dzīvokļa kopplatība, m2                 0
# Telpu skaits telpu grupā                0
# Istabu skaits dzīvoklī                  0
# Garums                                  0
# Platums                                 0
# dtype: int64

# %%
data.describe()
# Out:
#        Darījuma summa, EUR  Pārdotā zemes kopplatība, m2  Būvju skaits  \
# count          2628.000000                   2628.000000   2628.000000
# mean          69906.966161                    109.811476      1.237062
# std           52838.906805                    120.669440      0.776342
# min            1000.000000                      2.350000      1.000000
# 25%           30000.000000                     48.425000      1.000000
# 50%           55000.000000                     81.285000      1.000000
# 75%          100000.000000                    124.275000      1.000000
# max          295000.000000                   2384.620000      8.000000
#
#        Būves virszemes stāvu skaits  Būves apbūves laukums, m2  \
# count                   2628.000000                2628.000000
# mean                       4.579148                1058.463394
# std                        1.605394                 674.225674
# min                        1.000000                  67.200000
# 25%                        4.000000                 591.600000
# 50%                        5.000000                 885.800000
# 75%                        5.000000                1432.500000
# max                       10.000000                4488.300000
#
#        Būves kopplatība, m2  Būves būvtilpums, m3  \
# count           2628.000000           2628.000000
# mean            4410.045510          15090.025114
# std             2716.280639           9679.842424
# min               69.900000            276.000000
# 25%             2302.975000           7616.250000
# 50%             3724.500000          12726.000000
# 75%             6568.300000          22674.500000
# max            10097.700000          37744.000000
#
#        Būves ekspluatācijas uzsākšanas gads  Būves fiziskais nolietojums, %  \
# count                           2628.000000                     2628.000000
# mean                            1989.656393                       15.828006
# std                               22.954024                       14.115871
# min                             1900.000000                        0.000000
# 25%                             1972.000000                        0.000000
# 50%                             1984.000000                       15.000000
# 75%                             2008.000000                       26.000000
# max                             2023.000000                       75.000000
#
#        Telpu grupas zemākais stāvs  Telpu grupas augstākais stāvs  \
# count                  2628.000000                    2628.000000
# mean                      2.790715                       2.826865
# std                       1.560711                       1.539015
# min                      -1.000000                      -1.000000
# 25%                       2.000000                       2.000000
# 50%                       3.000000                       3.000000
# 75%                       4.000000                       4.000000
# max                       9.000000                       9.000000
#
#        Telpu grupas platība, m2  Dzīvokļa kopplatība, m2  \
# count               2628.000000              2628.000000
# mean                  60.023478                55.736606
# std                   25.299337                21.533672
# min                    8.400000                 8.400000
# 25%                   44.975000                42.875000
# 50%                   56.650000                52.800000
# 75%                   70.900000                64.900000
# max                  250.600000               204.400000
#
#        Telpu skaits telpu grupā  Istabu skaits dzīvoklī       Garums  \
# count               2628.000000             2628.000000  2628.000000
# mean                   6.377854                2.400685    56.918852
# std                    2.029267                0.931020     0.129937
# min                    1.000000                1.000000    56.723056
# 25%                    5.000000                2.000000    56.858611
# 50%                    6.000000                2.000000    56.875000
# 75%                    8.000000                3.000000    57.076944
# max                   19.000000                7.000000    57.261944
#
#            Platums
# count  2628.000000
# mean     24.295052
# std       0.265791
# min      23.941944
# 25%      24.047778
# 50%      24.323611
# 75%      24.349722
# max      24.857778

# %%
corr = data.corr()
corr.shape
# Out:
# (17, 17)

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(corr, annot=True, fmt='.2f', annot_kws={'size':16}, cmap='coolwarm')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(7, 5))
sns.histplot(data=data, x='Darījuma summa, EUR', kde=True)
plt.ylabel('Skaits')
plt.show()

# %%
# Pielieoto logaritmisko tranformaciju
data['Darījuma summa, EUR'] = np.log1p(data['Darījuma summa, EUR'])

# %%
plt.figure(figsize=(7, 4))
sns.histplot(data=data, x='Darījuma summa, EUR', kde=True)
plt.ylabel('Skaits')
plt.show()
